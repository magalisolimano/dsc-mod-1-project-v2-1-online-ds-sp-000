# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Magali Solimano
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name: Jeff Herman
# * Blog post URL:

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
## Load the data (11 files)
df1 = pd.read_csv('zippedData/bom.movie_gross.csv.gz', compression='gzip')
df2 = pd.read_csv('zippedData/imdb.name.basics.csv.gz', compression='gzip')
df3 = pd.read_csv('zippedData/imdb.title.akas.csv.gz', compression='gzip')
df4 = pd.read_csv('zippedData/imdb.title.basics.csv.gz', compression='gzip') 
df5 = pd.read_csv('zippedData/imdb.title.crew.csv.gz', compression='gzip')
df6 = pd.read_csv('zippedData/imdb.title.principals.csv.gz', compression='gzip')
df7 = pd.read_csv('zippedData/imdb.title.ratings.csv.gz', compression='gzip')
df8 = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t', compression='gzip')
df9 = pd.read_csv('zippedData/rt.reviews.tsv.gz', compression='gzip', delimiter='\t', encoding='iso-8859-1')
df10 = pd.read_csv('zippedData/tmdb.movies.csv.gz', compression='gzip')
df11 = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', compression='gzip')

# %%
# Explore the dataframes and data types
print(df1.info())
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# None
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
print(df2.info())
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB
# None
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
print(df3.info())
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB
# None
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
print(df4.info())
df4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
print(df5.info())
df5.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB
# None
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
print(df6.info())
df6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
print(df7.info())
df7.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
print(df8.info())
df8.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB
# None
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
print(df9.info())
df9.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB
# None
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
print(df10.info())
df10.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# None
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
print(df11.info())
df11.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
## QUESTIONS - PART 1: WHAT MOVIES ARE TOP REVENUE AND ROI GENERATORS? WHAT ARE THE TOP STUDIOS?

# %%
#df1 and #df11 have revenue cols -- compare these results. Can the dfs be joined?

# %%
# Convert budget and revenue cols to float dtype; release_date to datetime. Remove '$' and ','.
df11['production_budget'] = df11['production_budget'].map(lambda x: float(x.replace("$", "").replace(',','')))
df11['domestic_gross'] = df11['domestic_gross'].map(lambda x: float(x.replace("$", "").replace(',','')))
df11['worldwide_gross'] = df11['worldwide_gross'].map(lambda x: float(x.replace("$", "").replace(',','')))
df11['release_date'] = pd.to_datetime(df11['release_date'])
df11['year'] = pd.DatetimeIndex(df11['release_date']).year

# Confirm that dtype conversions worked and that null values did not increase
display(df11.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
#  6   year               5782 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 316.3+ KB
# None

# %%
df11 = df11.rename(columns={"movie": "title"})
df11.head()
# Out:
#    id release_date                                        title  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  year
# 0        425000000.0     760507625.0     2.776345e+09  2009
# 1        410600000.0     241063875.0     1.045664e+09  2011
# 2        350000000.0      42762350.0     1.497624e+08  2019
# 3        330600000.0     459005868.0     1.403014e+09  2015
# 4        317000000.0     620181382.0     1.316722e+09  2017

# %%
# Compare top gross: df1 vs df11

# %%
display(df1.sort_values(by=['domestic_gross'], ascending=False).head(20))
df11.sort_values(by=['domestic_gross'], ascending=False).head(20)
# Out:
#                                 title studio  domestic_gross foreign_gross  \
# 1872     Star Wars: The Force Awakens     BV     936700000.0       1,131.6
# 3080                    Black Panther     BV     700100000.0     646900000
# 3079           Avengers: Infinity War     BV     678800000.0       1,369.5
# 1873                   Jurassic World   Uni.     652300000.0       1,019.4
# 727             Marvel's The Avengers     BV     623400000.0     895500000
# 2758         Star Wars: The Last Jedi     BV     620200000.0     712400000
# 3082                    Incredibles 2     BV     608600000.0     634200000
# 2323     Rogue One: A Star Wars Story     BV     532200000.0     523900000
# 2759      Beauty and the Beast (2017)     BV     504000000.0     759500000
# 2324                     Finding Dory     BV     486300000.0     542300000
# 1875          Avengers: Age of Ultron     BV     459000000.0     946400000
# 729             The Dark Knight Rises     WB     448100000.0     636800000
# 1131  The Hunger Games: Catching Fire    LGF     424700000.0     440300000
# 3081   Jurassic World: Fallen Kingdom   Uni.     417700000.0     891800000
# 0                         Toy Story 3     BV     415000000.0     652000000
# 2767                     Wonder Woman     WB     412600000.0     409300000
# 1128                       Iron Man 3     BV     409000000.0     805800000
# 2322       Captain America: Civil War     BV     408100000.0     745200000
# 735                  The Hunger Games    LGF     408000000.0     286400000
# 2762   Jumanji: Welcome to the Jungle   Sony     404500000.0     557600000
#
#       year
# 1872  2015
# 3080  2018
# 3079  2018
# 1873  2015
# 727   2012
# 2758  2017
# 3082  2018
# 2323  2016
# 2759  2017
# 2324  2016
# 1875  2015
# 729   2012
# 1131  2013
# 3081  2018
# 0     2010
# 2767  2017
# 1128  2013
# 2322  2016
# 735   2012
# 2762  2017
#       id release_date                                 title  \
# 5      6   2015-12-18  Star Wars Ep. VII: The Force Awakens
# 0      1   2009-12-18                                Avatar
# 41    42   2018-02-16                         Black Panther
# 6      7   2018-04-27                Avengers: Infinity War
# 42    43   1997-12-19                               Titanic
# 33    34   2015-06-12                        Jurassic World
# 26    27   2012-05-04                          The Avengers
# 4      5   2017-12-15     Star Wars Ep. VIII: The Last Jedi
# 43    44   2018-06-15                         Incredibles 2
# 74    75   2008-07-18                       The Dark Knight
# 44    45   2016-12-16          Rogue One: A Star Wars Story
# 134   35   2017-03-17                  Beauty and the Beast
# 45    46   2016-06-17                          Finding Dory
# 303    4   1999-05-19   Star Wars Ep. I: The Phantom Menace
# 3464  65   1977-05-25          Star Wars Ep. IV: A New Hope
# 3      4   2015-05-01               Avengers: Age of Ultron
# 10    11   2012-07-20                 The Dark Knight Rises
# 692   93   2004-05-19                               Shrek 2
# 3525  26   1982-06-11             ET: The Extra-Terrestrial
# 95    96   2019-03-08                        Captain Marvel
#
#       production_budget  domestic_gross  worldwide_gross  year
# 5           306000000.0     936662225.0     2.053311e+09  2015
# 0           425000000.0     760507625.0     2.776345e+09  2009
# 41          200000000.0     700059566.0     1.348258e+09  2018
# 6           300000000.0     678815482.0     2.048134e+09  2018
# 42          200000000.0     659363944.0     2.208208e+09  1997
# 33          215000000.0     652270625.0     1.648855e+09  2015
# 26          225000000.0     623279547.0     1.517936e+09  2012
# 4           317000000.0     620181382.0     1.316722e+09  2017
# 43          200000000.0     608581744.0     1.242521e+09  2018
# 74          185000000.0     533720947.0     1.001996e+09  2008
# 44          200000000.0     532177324.0     1.049103e+09  2016
# 134         160000000.0     504014165.0     1.259200e+09  2017
# 45          200000000.0     486295561.0     1.021215e+09  2016
# 303         115000000.0     474544677.0     1.027045e+09  1999
# 3464         11000000.0     460998007.0     7.865980e+08  1977
# 3           330600000.0     459005868.0     1.403014e+09  2015
# 10          275000000.0     448139099.0     1.084439e+09  2012
# 692          70000000.0     441226247.0     9.370081e+08  2004
# 3525         10500000.0     435110554.0     7.929653e+08  1982
# 95          175000000.0     426525952.0     1.123062e+09  2019

# %%
# There is overlap between df1 & df11. But, df11 has more movie entries (incl. several top revenue generators) that are not in df1.
# df1 might not have a particular studio's movies.

# %%
# Set index to title.
# Join df11 and df1--left join to bring in df1's studio info.

# %%
df1.set_index('title', inplace = True)
df11.set_index('title', inplace = True)

# %%
df_financials = df11.join(df1, how='left', rsuffix='_right')
display(df_financials.info())
df_financials.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5782 entries, #Horror to é·æ±ä¸è (CJ7)
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5782 non-null   int64
#  1   release_date          5782 non-null   datetime64[ns]
#  2   production_budget     5782 non-null   float64
#  3   domestic_gross        5782 non-null   float64
#  4   worldwide_gross       5782 non-null   float64
#  5   year                  5782 non-null   int64
#  6   studio                1246 non-null   object
#  7   domestic_gross_right  1245 non-null   float64
#  8   foreign_gross         1086 non-null   object
#  9   year_right            1247 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 496.9+ KB
# None
#                             id release_date  production_budget  \
# title
# #Horror                     16   2015-11-20          1500000.0
# (500) Days of Summer        55   2009-07-17          7500000.0
# 10 Cloverfield Lane         54   2016-03-11          5000000.0
# 10 Days in a Madhouse       48   2015-11-11         12000000.0
# 10 Things I Hate About You  63   1999-03-31         13000000.0
#
#                             domestic_gross  worldwide_gross  year studio  \
# title
# #Horror                                0.0              0.0  2015    NaN
# (500) Days of Summer            32425665.0       34439060.0  2009    NaN
# 10 Cloverfield Lane             72082999.0      108286422.0  2016   Par.
# 10 Days in a Madhouse              14616.0          14616.0  2015    NaN
# 10 Things I Hate About You      38177966.0       60413950.0  1999    NaN
#
#                             domestic_gross_right foreign_gross  year_right
# title
# #Horror                                      NaN           NaN         NaN
# (500) Days of Summer                         NaN           NaN         NaN
# 10 Cloverfield Lane                   72100000.0      38100000      2016.0
# 10 Days in a Madhouse                        NaN           NaN         NaN
# 10 Things I Hate About You                   NaN           NaN         NaN

# %%
# Drop df1 revenue data since they seem to round, while df11's revenue data is more precise.
# Drop foreign_gross, year_right.

# %%
df_financials = df_financials.drop(columns=['domestic_gross_right', 'foreign_gross', 'year_right'])

# %%
# Convert "0" values to NaN
df_financials['production_budget'] = df_financials['production_budget'].replace(0.0, np.nan)
df_financials['domestic_gross'] = df_financials['domestic_gross'].replace(0.0, np.nan)
df_financials['worldwide_gross'] = df_financials['worldwide_gross'].replace(0.0, np.nan)


# Convert values to millions
df_financials['production_budget_m'] = (df_financials['production_budget'] / 1000000).round(1)
df_financials['domestic_gross_m'] = (df_financials['domestic_gross'] / 1000000).round(1)
df_financials['worldwide_gross_m'] = (df_financials['worldwide_gross'] / 1000000).round(1)

df_financials.head(10)
# Out:
#                             id release_date  production_budget  \
# title
# #Horror                     16   2015-11-20          1500000.0
# (500) Days of Summer        55   2009-07-17          7500000.0
# 10 Cloverfield Lane         54   2016-03-11          5000000.0
# 10 Days in a Madhouse       48   2015-11-11         12000000.0
# 10 Things I Hate About You  63   1999-03-31         13000000.0
# 10,000 B.C.                 51   2008-03-07        105000000.0
# 102 Dalmatians               6   2000-11-22         85000000.0
# 10th & Wolf                 32   2006-08-18          8000000.0
# 11:14                       90   2005-08-12          6000000.0
# 12 Angry Men                36   1957-04-13           340000.0
#
#                             domestic_gross  worldwide_gross  year studio  \
# title
# #Horror                                NaN              NaN  2015    NaN
# (500) Days of Summer            32425665.0       34439060.0  2009    NaN
# 10 Cloverfield Lane             72082999.0      108286422.0  2016   Par.
# 10 Days in a Madhouse              14616.0          14616.0  2015    NaN
# 10 Things I Hate About You      38177966.0       60413950.0  1999    NaN
# 10,000 B.C.                     94784201.0      269065678.0  2008    NaN
# 102 Dalmatians                  66941559.0       66941559.0  2000    NaN
# 10th & Wolf                        54702.0         143782.0  2006    NaN
# 11:14                                  NaN              NaN  2005    NaN
# 12 Angry Men                           NaN              NaN  1957    NaN
#
#                             production_budget_m  domestic_gross_m  \
# title
# #Horror                                     1.5               NaN
# (500) Days of Summer                        7.5              32.4
# 10 Cloverfield Lane                         5.0              72.1
# 10 Days in a Madhouse                      12.0               0.0
# 10 Things I Hate About You                 13.0              38.2
# 10,000 B.C.                               105.0              94.8
# 102 Dalmatians                             85.0              66.9
# 10th & Wolf                                 8.0               0.1
# 11:14                                       6.0               NaN
# 12 Angry Men                                0.3               NaN
#
#                             worldwide_gross_m
# title
# #Horror                                   NaN
# (500) Days of Summer                     34.4
# 10 Cloverfield Lane                     108.3
# 10 Days in a Madhouse                     0.0
# 10 Things I Hate About You               60.4
# 10,000 B.C.                             269.1
# 102 Dalmatians                           66.9
# 10th & Wolf                               0.1
# 11:14                                     NaN
# 12 Angry Men                              NaN

# %%
# Create new cols for foreign_gross, net_revenue, ROI
df_financials['foreign_gross_m'] = (df_financials['worldwide_gross_m'] - df_financials['domestic_gross_m']).round(1)
df_financials['net_revenue_m'] = (df_financials['worldwide_gross_m'] - df_financials['production_budget_m']).round(1)
df_financials['ROI'] = ((df_financials['worldwide_gross'] - df_financials['production_budget']) / df_financials['production_budget']).round(2)
df_financials['ROIpct'] = (((df_financials['worldwide_gross'] - df_financials['production_budget']) / df_financials['production_budget'])*100).round(2)
df_financials.head()
# Out:
#                             id release_date  production_budget  \
# title
# #Horror                     16   2015-11-20          1500000.0
# (500) Days of Summer        55   2009-07-17          7500000.0
# 10 Cloverfield Lane         54   2016-03-11          5000000.0
# 10 Days in a Madhouse       48   2015-11-11         12000000.0
# 10 Things I Hate About You  63   1999-03-31         13000000.0
#
#                             domestic_gross  worldwide_gross  year studio  \
# title
# #Horror                                NaN              NaN  2015    NaN
# (500) Days of Summer            32425665.0       34439060.0  2009    NaN
# 10 Cloverfield Lane             72082999.0      108286422.0  2016   Par.
# 10 Days in a Madhouse              14616.0          14616.0  2015    NaN
# 10 Things I Hate About You      38177966.0       60413950.0  1999    NaN
#
#                             production_budget_m  domestic_gross_m  \
# title
# #Horror                                     1.5               NaN
# (500) Days of Summer                        7.5              32.4
# 10 Cloverfield Lane                         5.0              72.1
# 10 Days in a Madhouse                      12.0               0.0
# 10 Things I Hate About You                 13.0              38.2
#
#                             worldwide_gross_m  foreign_gross_m  net_revenue_m  \
# title
# #Horror                                   NaN              NaN            NaN
# (500) Days of Summer                     34.4              2.0           26.9
# 10 Cloverfield Lane                     108.3             36.2          103.3
# 10 Days in a Madhouse                     0.0              0.0          -12.0
# 10 Things I Hate About You               60.4             22.2           47.4
#
#                               ROI   ROIpct
# title
# #Horror                       NaN      NaN
# (500) Days of Summer         3.59   359.19
# 10 Cloverfield Lane         20.66  2065.73
# 10 Days in a Madhouse       -1.00   -99.88
# 10 Things I Hate About You   3.65   364.72

# %%
# reset index
df_financials.reset_index(inplace = True)

# %%
# Check for duplicates. Explore if need to remove or can keep.
df_financials['title'].value_counts()
# Out:
# Home                            3
# King Kong                       3
# Halloween                       3
# Casino Royale                   2
# Hamlet                          2
#                                ..
# The Bridge on the River Kwai    1
# The Work and the Story          1
# Deep Throat                     1
# Romantic Schemer                1
# We Are Your Friends             1
# Name: title, Length: 5698, dtype: int64

# %%
df_financials[df_financials['title'].duplicated() == True]
# Out:
#                              title  id release_date  production_budget  \
# 33    20,000 Leagues Under the Sea  15   1916-12-24           200000.0
# 141      A Nightmare on Elm Street  17   1984-11-09          1800000.0
# 232                        Aladdin  33   1992-11-11         28000000.0
# 246            Alice in Wonderland  60   1951-07-28          3000000.0
# 406    Around the World in 80 Days  21   1956-10-17          6000000.0
# ...                            ...  ..          ...                ...
# 5351                        Trance  31   2012-12-31           950000.0
# 5408                      Twilight  20   1998-03-06         20000000.0
# 5463                 Unforgettable   4   2017-04-21         12000000.0
# 5472                       Unknown  84   2006-11-03          3700000.0
# 5512                         Venom  14   2005-09-16         25000000.0
#
#       domestic_gross  worldwide_gross  year studio  production_budget_m  \
# 33         8000000.0        8000000.0  1916    NaN                  0.2
# 141       25504513.0       25504513.0  1984    NaN                  1.8
# 232      217350219.0      504050219.0  1992    NaN                 28.0
# 246              NaN              NaN  1951    NaN                  3.0
# 406       42000000.0       42000000.0  1956    NaN                  6.0
# ...              ...              ...   ...    ...                  ...
# 5351             NaN              NaN  2012   FoxS                  1.0
# 5408      15055091.0       15055091.0  1998    NaN                 20.0
# 5463      11368012.0       16221211.0  2017    NaN                 12.0
# 5472         26403.0        3355048.0  2006     WB                  3.7
# 5512        881745.0         881745.0  2005    NaN                 25.0
#
#       domestic_gross_m  worldwide_gross_m  foreign_gross_m  net_revenue_m  \
# 33                 8.0                8.0              0.0            7.8
# 141               25.5               25.5              0.0           23.7
# 232              217.4              504.1            286.7          476.1
# 246                NaN                NaN              NaN            NaN
# 406               42.0               42.0              0.0           36.0
# ...                ...                ...              ...            ...
# 5351               NaN                NaN              NaN            NaN
# 5408              15.1               15.1              0.0           -4.9
# 5463              11.4               16.2              4.8            4.2
# 5472               0.0                3.4              3.4           -0.3
# 5512               0.9                0.9              0.0          -24.1
#
#         ROI   ROIpct
# 33    39.00  3900.00
# 141   13.17  1316.92
# 232   17.00  1700.18
# 246     NaN      NaN
# 406    6.00   600.00
# ...     ...      ...
# 5351    NaN      NaN
# 5408  -0.25   -24.72
# 5463   0.35    35.18
# 5472  -0.09    -9.32
# 5512  -0.96   -96.47
#
# [84 rows x 15 columns]

# %%
# view selection of rows with duplicate titles
df_financials.sort_values('title').iloc[231:250, :]
# Out:
#                                                  title   id release_date  \
# 231                                            Aladdin   81   2019-05-24
# 232                                            Aladdin   33   1992-11-11
# 233                                          Alatriste   81   2007-12-31
# 234                                       Albert Nobbs   67   2011-12-21
# 235                                   Albino Alligator   65   1997-01-17
# 236                                        Alex & Emma   70   2003-06-20
# 237                                         Alex Cross  100   2012-10-19
# 238                 Alex Rider: Operation Stormbreaker   34   2006-10-13
# 239                                          Alexander   51   2004-11-24
# 240  Alexander and the Terrible, Horrible, No Good,...   44   2014-10-10
# 241                           Alexander's Ragtime Band   18   1938-05-24
# 242                                              Alfie   12   2004-11-05
# 243                                                Ali   45   2001-12-25
# 244                    Alice Through the Looking Glass   26   2016-05-27
# 246                                Alice in Wonderland   60   1951-07-28
# 245                                Alice in Wonderland   51   2010-03-05
# 247                                              Alien   21   1979-05-25
# 248                                            Alien 3   17   1992-05-22
# 249                                     Alien Uprising   44   2013-06-21
#
#      production_budget  domestic_gross  worldwide_gross  year studio  \
# 231        182000000.0     246734314.0     6.192343e+08  2019    NaN
# 232         28000000.0     217350219.0     5.040502e+08  1992    NaN
# 233         28000000.0             NaN     2.286048e+07  2007    NaN
# 234          7500000.0       3014696.0     8.539003e+06  2011  RAtt.
# 235          5000000.0        353480.0     3.534800e+05  1997    NaN
# 236         30000000.0      14208384.0     1.535858e+07  2003    NaN
# 237         35000000.0      25888412.0     3.542676e+07  2012   LG/S
# 238         40000000.0        659210.0     2.072245e+07  2006    NaN
# 239        155000000.0      34297191.0     1.672972e+08  2004    NaN
# 240         28000000.0      66954149.0     1.013793e+08  2014     BV
# 241          2000000.0       4000000.0     4.000000e+06  1938    NaN
# 242         40000000.0      13395939.0     3.519594e+07  2004    NaN
# 243        109000000.0      58183966.0     8.768397e+07  2001    NaN
# 244        170000000.0      77042381.0     2.769281e+08  2016     BV
# 246          3000000.0             NaN              NaN  1951    NaN
# 245        200000000.0     334191110.0     1.025491e+09  2010    NaN
# 247         10700000.0      80930630.0     2.036289e+08  1979    NaN
# 248         55000000.0      54927174.0     1.585000e+08  1992    NaN
# 249          2500000.0             NaN              NaN  2013    NaN
#
#      production_budget_m  domestic_gross_m  worldwide_gross_m  \
# 231                182.0             246.7              619.2
# 232                 28.0             217.4              504.1
# 233                 28.0               NaN               22.9
# 234                  7.5               3.0                8.5
# 235                  5.0               0.4                0.4
# 236                 30.0              14.2               15.4
# 237                 35.0              25.9               35.4
# 238                 40.0               0.7               20.7
# 239                155.0              34.3              167.3
# 240                 28.0              67.0              101.4
# 241                  2.0               4.0                4.0
# 242                 40.0              13.4               35.2
# 243                109.0              58.2               87.7
# 244                170.0              77.0              276.9
# 246                  3.0               NaN                NaN
# 245                200.0             334.2             1025.5
# 247                 10.7              80.9              203.6
# 248                 55.0              54.9              158.5
# 249                  2.5               NaN                NaN
#
#      foreign_gross_m  net_revenue_m    ROI   ROIpct
# 231            372.5          437.2   2.40   240.24
# 232            286.7          476.1  17.00  1700.18
# 233              NaN           -5.1  -0.18   -18.36
# 234              5.5            1.0   0.14    13.85
# 235              0.0           -4.6  -0.93   -92.93
# 236              1.2          -14.6  -0.49   -48.80
# 237              9.5            0.4   0.01     1.22
# 238             20.0          -19.3  -0.48   -48.19
# 239            133.0           12.3   0.08     7.93
# 240             34.4           73.4   2.62   262.07
# 241              0.0            2.0   1.00   100.00
# 242             21.8           -4.8  -0.12   -12.01
# 243             29.5          -21.3  -0.20   -19.56
# 244            199.9          106.9   0.63    62.90
# 246              NaN            NaN    NaN      NaN
# 245            691.3          825.5   4.13   412.75
# 247            122.7          192.9  18.03  1803.07
# 248            103.6          103.5   1.88   188.18
# 249              NaN            NaN    NaN      NaN

# %%
# Duplicate movie titles are due to movie being re-released years later. 
# Keep all rows and create new col 'title_yr'. 
df_financials['title_yr'] = df_financials['title'].str.cat(df_financials.year.astype(str), sep = '-')
df_financials.head()
# Out:
#                         title  id release_date  production_budget  \
# 0                     #Horror  16   2015-11-20          1500000.0
# 1        (500) Days of Summer  55   2009-07-17          7500000.0
# 2         10 Cloverfield Lane  54   2016-03-11          5000000.0
# 3       10 Days in a Madhouse  48   2015-11-11         12000000.0
# 4  10 Things I Hate About You  63   1999-03-31         13000000.0
#
#    domestic_gross  worldwide_gross  year studio  production_budget_m  \
# 0             NaN              NaN  2015    NaN                  1.5
# 1      32425665.0       34439060.0  2009    NaN                  7.5
# 2      72082999.0      108286422.0  2016   Par.                  5.0
# 3         14616.0          14616.0  2015    NaN                 12.0
# 4      38177966.0       60413950.0  1999    NaN                 13.0
#
#    domestic_gross_m  worldwide_gross_m  foreign_gross_m  net_revenue_m    ROI  \
# 0               NaN                NaN              NaN            NaN    NaN
# 1              32.4               34.4              2.0           26.9   3.59
# 2              72.1              108.3             36.2          103.3  20.66
# 3               0.0                0.0              0.0          -12.0  -1.00
# 4              38.2               60.4             22.2           47.4   3.65
#
#     ROIpct                         title_yr
# 0      NaN                     #Horror-2015
# 1   359.19        (500) Days of Summer-2009
# 2  2065.73         10 Cloverfield Lane-2016
# 3   -99.88       10 Days in a Madhouse-2015
# 4   364.72  10 Things I Hate About You-1999

# %%
df_financials[df_financials['title_yr'].duplicated() == True]
# Out:
#      title  id release_date  production_budget  domestic_gross  \
# 2020  Home  60   2009-04-23           500000.0         15433.0
#
#       worldwide_gross  year studio  production_budget_m  domestic_gross_m  \
# 2020       44793168.0  2009    NaN                  0.5               0.0
#
#       worldwide_gross_m  foreign_gross_m  net_revenue_m    ROI   ROIpct  \
# 2020               44.8             44.8           44.3  88.59  8858.63
#
#        title_yr
# 2020  Home-2009

# %%
df_financials.sort_values('title').iloc[2017:2022, :]
# Out:
#             title  id release_date  production_budget  domestic_gross  \
# 2017  Holy Motors  25   2012-10-17          4000000.0        641054.0
# 2020         Home  60   2009-04-23           500000.0         15433.0
# 2019         Home  56   2009-06-05         12000000.0             NaN
# 2018         Home  44   2015-03-27        130000000.0     177397510.0
# 2021   Home Again  57   2017-09-08         15000000.0      27020284.0
#
#       worldwide_gross  year studio  production_budget_m  domestic_gross_m  \
# 2017        4230426.0  2012     IM                  4.0               0.6
# 2020       44793168.0  2009    NaN                  0.5               0.0
# 2019              NaN  2009    NaN                 12.0               NaN
# 2018      385997896.0  2015    NaN                130.0             177.4
# 2021       37336874.0  2017    ORF                 15.0              27.0
#
#       worldwide_gross_m  foreign_gross_m  net_revenue_m    ROI   ROIpct  \
# 2017                4.2              3.6            0.2   0.06     5.76
# 2020               44.8             44.8           44.3  88.59  8858.63
# 2019                NaN              NaN            NaN    NaN      NaN
# 2018              386.0            208.6          256.0   1.97   196.92
# 2021               37.3             10.3           22.3   1.49   148.91
#
#               title_yr
# 2017  Holy Motors-2012
# 2020         Home-2009
# 2019         Home-2009
# 2018         Home-2015
# 2021   Home Again-2017

# %%
# Home movie - Double entry for 2009 release--unable to determine which one has accurate data, both appear to have notable outliers. Remove two 2009 entries.
df_financials = df_financials.drop([2019, 2020])

# %%
df_financials[df_financials['title_yr'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [title, id, release_date, production_budget, domestic_gross, worldwide_gross, year, studio, production_budget_m, domestic_gross_m, worldwide_gross_m, foreign_gross_m, net_revenue_m, ROI, ROIpct, title_yr]
# Index: []

# %%
df_financials.sort_values('title').iloc[2017:2022, :]
# Out:
#                                title  id release_date  production_budget  \
# 2017                     Holy Motors  25   2012-10-17          4000000.0
# 2018                            Home  44   2015-03-27        130000000.0
# 2021                      Home Again  57   2017-09-08         15000000.0
# 2022                      Home Alone  92   1990-11-16         15000000.0
# 2023  Home Alone 2: Lost in New York  89   1992-11-20         20000000.0
#
#       domestic_gross  worldwide_gross  year studio  production_budget_m  \
# 2017        641054.0        4230426.0  2012     IM                  4.0
# 2018     177397510.0      385997896.0  2015    NaN                130.0
# 2021      27020284.0       37336874.0  2017    ORF                 15.0
# 2022     285761243.0      476684675.0  1990    NaN                 15.0
# 2023     173585516.0      358994850.0  1992    NaN                 20.0
#
#       domestic_gross_m  worldwide_gross_m  foreign_gross_m  net_revenue_m  \
# 2017               0.6                4.2              3.6            0.2
# 2018             177.4              386.0            208.6          256.0
# 2021              27.0               37.3             10.3           22.3
# 2022             285.8              476.7            190.9          461.7
# 2023             173.6              359.0            185.4          339.0
#
#         ROI   ROIpct                             title_yr
# 2017   0.06     5.76                     Holy Motors-2012
# 2018   1.97   196.92                            Home-2015
# 2021   1.49   148.91                      Home Again-2017
# 2022  30.78  3077.90                      Home Alone-1990
# 2023  16.95  1694.97  Home Alone 2: Lost in New York-1992

# %%
# Create month col
df_financials['month_num'] = pd.DatetimeIndex(df_financials['release_date']).month
df_financials['month'] = pd.to_datetime(df_financials['month_num'], format='%m').dt.month_name().str.slice(stop=3)
df_financials.head()
# Out:
#                         title  id release_date  production_budget  \
# 0                     #Horror  16   2015-11-20          1500000.0
# 1        (500) Days of Summer  55   2009-07-17          7500000.0
# 2         10 Cloverfield Lane  54   2016-03-11          5000000.0
# 3       10 Days in a Madhouse  48   2015-11-11         12000000.0
# 4  10 Things I Hate About You  63   1999-03-31         13000000.0
#
#    domestic_gross  worldwide_gross  year studio  production_budget_m  \
# 0             NaN              NaN  2015    NaN                  1.5
# 1      32425665.0       34439060.0  2009    NaN                  7.5
# 2      72082999.0      108286422.0  2016   Par.                  5.0
# 3         14616.0          14616.0  2015    NaN                 12.0
# 4      38177966.0       60413950.0  1999    NaN                 13.0
#
#    domestic_gross_m  worldwide_gross_m  foreign_gross_m  net_revenue_m    ROI  \
# 0               NaN                NaN              NaN            NaN    NaN
# 1              32.4               34.4              2.0           26.9   3.59
# 2              72.1              108.3             36.2          103.3  20.66
# 3               0.0                0.0              0.0          -12.0  -1.00
# 4              38.2               60.4             22.2           47.4   3.65
#
#     ROIpct                         title_yr  month_num month
# 0      NaN                     #Horror-2015         11   Nov
# 1   359.19        (500) Days of Summer-2009          7   Jul
# 2  2065.73         10 Cloverfield Lane-2016          3   Mar
# 3   -99.88       10 Days in a Madhouse-2015         11   Nov
# 4   364.72  10 Things I Hate About You-1999          3   Mar

# %%
# Examine distribution of data

# %%
display(df_financials.info())
display(df_financials[["production_budget_m", "domestic_gross_m", "worldwide_gross_m", "foreign_gross_m", "net_revenue_m", "ROI"]].apply(['mean', 'median', 'std']))
display(df_financials.quantile(q=0.75))
display(df_financials.quantile(q=0.90))
display(df_financials.quantile(q=0.95))
display(df_financials.quantile(q=0.99))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5780 entries, 0 to 5781
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                5780 non-null   object
#  1   id                   5780 non-null   int64
#  2   release_date         5780 non-null   datetime64[ns]
#  3   production_budget    5780 non-null   float64
#  4   domestic_gross       5233 non-null   float64
#  5   worldwide_gross      5414 non-null   float64
#  6   year                 5780 non-null   int64
#  7   studio               1246 non-null   object
#  8   production_budget_m  5780 non-null   float64
#  9   domestic_gross_m     5233 non-null   float64
#  10  worldwide_gross_m    5414 non-null   float64
#  11  foreign_gross_m      5233 non-null   float64
#  12  net_revenue_m        5414 non-null   float64
#  13  ROI                  5414 non-null   float64
#  14  ROIpct               5414 non-null   float64
#  15  title_yr             5780 non-null   object
#  16  month_num            5780 non-null   int64
#  17  month                5780 non-null   object
# dtypes: datetime64[ns](1), float64(10), int64(3), object(4)
# memory usage: 858.0+ KB
# None
#         production_budget_m  domestic_gross_m  worldwide_gross_m  \
# mean              31.596003         46.265507          97.697211
# median            17.000000         22.000000          33.300000
# std               41.816880         70.300669         178.874107
#
#         foreign_gross_m  net_revenue_m        ROI
# mean          54.506191      64.383487   4.109852
# median         9.400000      11.900000   0.880000
# std          117.793693     149.871371  30.468579
# id                     7.500000e+01
# production_budget      4.000000e+07
# domestic_gross         5.759825e+07
# worldwide_gross        1.044737e+08
# year                   2.012000e+03
# production_budget_m    4.000000e+01
# domestic_gross_m       5.760000e+01
# worldwide_gross_m      1.044750e+02
# foreign_gross_m        5.330000e+01
# net_revenue_m          6.740000e+01
# ROI                    2.967500e+00
# ROIpct                 2.965375e+02
# month_num              1.000000e+01
# Name: 0.75, dtype: float64
# id                     9.000000e+01
# production_budget      8.000000e+07
# domestic_gross         1.196277e+08
# worldwide_gross        2.596225e+08
# year                   2.016000e+03
# production_budget_m    8.000000e+01
# domestic_gross_m       1.196600e+02
# worldwide_gross_m      2.596100e+02
# foreign_gross_m        1.531800e+02
# net_revenue_m          1.884400e+02
# ROI                    7.157000e+00
# ROIpct                 7.157060e+02
# month_num              1.200000e+01
# Name: 0.9, dtype: float64
# id                     9.500000e+01
# production_budget      1.200000e+08
# domestic_gross         1.766168e+08
# worldwide_gross        4.102847e+08
# year                   2.017000e+03
# production_budget_m    1.200000e+02
# domestic_gross_m       1.766400e+02
# worldwide_gross_m      4.103150e+02
# foreign_gross_m        2.628400e+02
# net_revenue_m          3.186850e+02
# ROI                    1.234350e+01
# ROIpct                 1.234325e+03
# month_num              1.200000e+01
# Name: 0.95, dtype: float64
# id                     9.900000e+01
# production_budget      2.000000e+08
# domestic_gross         3.369421e+08
# worldwide_gross        8.938658e+08
# year                   2.019000e+03
# production_budget_m    2.000000e+02
# domestic_gross_m       3.369080e+02
# worldwide_gross_m      8.938990e+02
# foreign_gross_m        5.905440e+02
# net_revenue_m          7.644130e+02
# ROI                    5.426760e+01
# ROIpct                 5.426570e+03
# month_num              1.200000e+01
# Name: 0.99, dtype: float64

# %%
# Domestic and worldwide gross revenue, net revenue, ROI are positively skewed--mean is larger than median, with large outliers distorting the mean.

# %%
df_financials.hist(column=['worldwide_gross_m'], bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd99fa005c0>]],
#       dtype=object)

# %%
df_financials.boxplot(column=['worldwide_gross_m'])

# %%
df_financials.boxplot(column=['ROI'])

# %%
# Number of movies in 75th, 90th, 99th percentiles - By worldwide gross revenue
print(f"Number of movies in 75th percentile: {len(df_financials[df_financials['worldwide_gross_m']>1.044750e+02])}")    
print(f"Number of movies in 90th percentile: {len(df_financials[df_financials['worldwide_gross_m']>2.596100e+02])}")
print(f"Number of movies in 95th percentile: {len(df_financials[df_financials['worldwide_gross_m']>4.103150e+02])}")
print(f"Number of movies in 99th percentile: {len(df_financials[df_financials['worldwide_gross_m']>8.938990e+02])}")
# Out:
# Number of movies in 75th percentile: 1354
# Number of movies in 90th percentile: 542
# Number of movies in 95th percentile: 271
# Number of movies in 99th percentile: 55

# %%
# Q1: What movies are the top gross revenue generators? (including outliers)

# Create new df - movies with gross revenue above 90th percentile
df_grossrev_99p = df_financials[df_financials.worldwide_gross_m >= 8.938658e+02].sort_values('worldwide_gross_m', ascending = False)
display(df_grossrev_99p.shape)

# top 25
df_grossrev_top25 = df_financials.sort_values('worldwide_gross_m', ascending = False).head(25)
display(df_grossrev_top25.shape)
# Out:
# (55, 18)
# (25, 18)

# %%
# Graph gross revenue movies

ax1 = df_grossrev_99p.plot.barh(x= 'title', 
                                y= 'worldwide_gross_m', 
                                color = 'green', 
                                stacked=False, 
                                rot=0, 
                                figsize=(12,12), 
                                label = '_nolegend_')
ax1.set(
    title='Top Revenue Grossing Movies',
    xlabel='Millions $',
    ylabel='Movies')
ax1.invert_yaxis()

ax2 = df_grossrev_99p.plot.barh(x= 'title', 
                                y = 'ROIpct', 
                                color = 'green', 
                                stacked=False, 
                                rot=0, 
                                figsize=(12,10),
                                label = '_nolegend_')

ax2.set(
    title='ROI of Top Revenue Grossing Movies',
    xlabel='ROI (%)',
    ylabel='Movies')
ax2.invert_yaxis()

plt.style.use('ggplot')
plt.show()
# Out:
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:572: UserWarning: The handle <BarContainer object of 55 artists> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Create figure
fig, ax1 = plt.subplots(figsize=(18,12))

#Assign chart variables
title = df_grossrev_99p['title']
ww_gross = df_grossrev_99p['worldwide_gross_m']
ROIp = df_grossrev_99p['ROIpct']

#Identify two y-axes using the same x-axis (i.e., the second (left) y-axis will use the same x-axis 
ax2 = ax1.twinx()

#Create standard bar chart of gross revenue on the left y-axis
plt1 = ax1.bar(title, ww_gross, color='lightsteelblue', label='Worldwide gross revenue')

#Add line plot of ROI to same chart on the right y-axis. Set markers to '.' and remove line.
plt2 = ax2.plot(title, ROIp, marker = '.', markersize = 12, color='navy', linestyle='None', label='ROI')

#X-axis label formatting: rotate and center
ax1.set_xticklabels(title, rotation=90, ha='center')

#Y-axis label formatting: Set labels and change colors of labels to match chart content
ax1.set_ylabel('Gross Revenue (Millions $)', color='gray')
ax2.set_ylabel('ROI (Percent)', color='navy')

#Y-axis tick marks: Set min, max, intervals
ax1.set_yticks(np.arange (0, 3250, 250))
ax2.set_yticks(np.arange (0, 3250, 250))

labels = [plt1.get_label(), plt2[0].get_label()]
ax1.legend([plt1,plt2[0]],labels, fontsize=16)

plt.show()
# Out:
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
type(plt2[0])
# Out:
# matplotlib.lines.Line2D

# %%
# Question: What is total revenue trend per year?
df_financials.groupby(['year'])['worldwide_gross_m'].agg('sum')
# Out:
# year
# 1915       11.0
# 1916        8.0
# 1920        3.0
# 1925       31.0
# 1927        0.0
#          ...
# 2016    28768.4
# 2017    28429.7
# 2018    26094.3
# 2019     6676.6
# 2020        0.0
# Name: worldwide_gross_m, Length: 96, dtype: float64

# %%
# Question: What are the top grossing studios by year?
# Create studio df, remove NaN
df_studio_tot_rev = df_financials[df_financials['studio'].notnull()]
df_studio_tot_rev.year.value_counts(ascending = True).sort_index()
# Out:
# 1967      1
# 1984      1
# 1986      2
# 1999      1
# 2001      2
# 2003      2
# 2005      1
# 2006      1
# 2010    181
# 2011    162
# 2012    145
# 2013    139
# 2014    126
# 2015    145
# 2016    142
# 2017    100
# 2018     95
# Name: year, dtype: int64

# %%
# More studio data available from 2010 onwards
# Sum of each studio's total revenue from 2010-present
df_studio_tot_rev = df_studio_tot_rev[df_studio_tot_rev.year>2010].groupby('studio')['worldwide_gross_m'].agg(['sum'])
df_studio_tot_rev.reset_index(inplace = True)
df_studio_tot_rev.head()
# Out:
#    studio    sum
# 0     A24  400.0
# 1     ALP    2.9
# 2  Affirm   31.4
# 3     Alc    0.2
# 4  Amazon    7.0

# %%
df_studio_tot_rev.columns
# Out:
# Index(['studio', 'sum'], dtype='object')

# %%
# Rename column to 'total_revenue'
df_studio_tot_rev = df_studio_tot_rev.rename(columns={"sum": "total_revenue"})
df_studio_tot_rev.columns
# Out:
# Index(['studio', 'total_revenue'], dtype='object')

# %%
# Sort in alphabetical order by studio
df_studio_tot_rev = df_studio_tot_rev.sort_values(by='studio', ascending=True)
df_studio_tot_rev
# Out:
#      studio  total_revenue
# 0       A24          400.0
# 1       ALP            2.9
# 2    Affirm           31.4
# 3       Alc            0.2
# 4    Amazon            7.0
# ..      ...            ...
# 77       WB        19947.3
# 78  WB (NL)         7985.3
# 79      WHE            0.4
# 80    Wein.         2795.5
# 81     Yash           90.5
#
# [82 rows x 2 columns]

# %%
df_studio_tot_rev['total_revenue']
# Out:
# 0       400.0
# 1         2.9
# 2        31.4
# 3         0.2
# 4         7.0
#        ...
# 77    19947.3
# 78     7985.3
# 79        0.4
# 80     2795.5
# 81       90.5
# Name: total_revenue, Length: 82, dtype: float64

# %%
# Top 20 studios by total revenue, 2010-2019
df_studio_tot_rev_2010_2019 = df_studio_tot_rev.sort_values('total_revenue', ascending = False).head(20)
df_studio_tot_rev_2010_2019.head()
# Out:
#    studio  total_revenue
# 12     BV        31139.9
# 74   Uni.        25541.2
# 27    Fox        24652.8
# 77     WB        19947.3
# 66   Sony        15579.1

# %%
fig, ax = plt.subplots(figsize=(14,6))

studio = df_studio_tot_rev_2010_2019['studio']
tot_revenue = df_studio_tot_rev_2010_2019['total_revenue']
ax.barh(studio, tot_revenue, color = 'navy')

ax.set_title('Top Studios by Total Revenue (2010-2019)')
ax.set_xlabel('Total Revenue (Millions $)')

ax.set_xticks(np.arange(0,37500, 2500))

ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %%
## Top studios by revenue from 2015-2019

# %%
# Top grossing studios (year 2015 to present)
# Create studio df, remove NaN
df_studio_tot_rev_2015_2019 = df_financials[df_financials['studio'].notnull()]
df_studio_tot_rev_2015_2019.head()
# Out:
#                                         title  id release_date  \
# 2                         10 Cloverfield Lane  54   2016-03-11
# 12                                  12 Strong  64   2018-01-19
# 13                           12 Years a Slave  18   2013-10-18
# 14                                  127 Hours   6   2010-11-05
# 16  13 Hours: The Secret Soldiers of Benghazi  30   2016-01-15
#
#     production_budget  domestic_gross  worldwide_gross  year studio  \
# 2           5000000.0      72082999.0      108286422.0  2016   Par.
# 12         35000000.0      45819713.0       71118378.0  2018     WB
# 13         20000000.0      56671993.0      181025343.0  2013   FoxS
# 14         18000000.0      18335230.0       60217171.0  2010   FoxS
# 16         50000000.0      52853219.0       69411370.0  2016   Par.
#
#     production_budget_m  domestic_gross_m  worldwide_gross_m  foreign_gross_m  \
# 2                   5.0              72.1              108.3             36.2
# 12                 35.0              45.8               71.1             25.3
# 13                 20.0              56.7              181.0            124.3
# 14                 18.0              18.3               60.2             41.9
# 16                 50.0              52.9               69.4             16.5
#
#     net_revenue_m    ROI   ROIpct  \
# 2           103.3  20.66  2065.73
# 12           36.1   1.03   103.20
# 13          161.0   8.05   805.13
# 14           42.2   2.35   234.54
# 16           19.4   0.39    38.82
#
#                                           title_yr  month_num month
# 2                         10 Cloverfield Lane-2016          3   Mar
# 12                                  12 Strong-2018          1   Jan
# 13                           12 Years a Slave-2013         10   Oct
# 14                                  127 Hours-2010         11   Nov
# 16  13 Hours: The Secret Soldiers of Benghazi-2016          1   Jan

# %%
df_studio_tot_rev_2015_2019 = df_studio_tot_rev_2015_2019[df_studio_tot_rev_2015_2019.year>2014].groupby('studio')['worldwide_gross_m'].agg(['sum'])
df_studio_tot_rev_2015_2019.reset_index(inplace = True)
df_studio_tot_rev_2015_2019.head()
# Out:
#    studio    sum
# 0     A24  342.7
# 1  Affirm   31.4
# 2     Alc    0.2
# 3  Amazon    7.0
# 4   Anch.   13.0

# %%
df_studio_tot_rev_2015_2019 = df_studio_tot_rev_2015_2019.rename(columns={"sum": "total_revenue"})
df_studio_tot_rev_2015_2019.head()
# Out:
#    studio  total_revenue
# 0     A24          342.7
# 1  Affirm           31.4
# 2     Alc            0.2
# 3  Amazon            7.0
# 4   Anch.           13.0

# %%
# Top 25 studios by total revenue, 2015-2019
df_studio_tot_rev_2015_2019 = df_studio_tot_rev_2015_2019.sort_values('total_revenue', ascending = False).head(20)
df_studio_tot_rev_2015_2019.head()
# Out:
#    studio  total_revenue
# 11     BV        18743.7
# 51   Uni.        16728.6
# 22    Fox        11788.1
# 54     WB        11521.5
# 45   Sony         6810.3

# %%
fig, ax = plt.subplots(figsize=(14,6))

studio_2015_2019 = df_studio_tot_rev_2015_2019['studio']
tot_revenue_2015_2019 = df_studio_tot_rev_2015_2019['total_revenue']
ax.barh(studio_2015_2019, tot_revenue_2015_2019, color = 'navy')

ax.set_title('Top Studios by Total Revenue (2015-2019)')
ax.set_xlabel('Total Revenue (Millions $)')

ax.set_xticks(np.arange(0,27500, 2500))

ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Plot top studios' revenue by year

# %%
# Top grossing studios by year: 2010-present
# Create studio df, remove NaN

df_studio_tot_rev_annual = df_financials[df_financials['studio'].notnull()]
df_studio_tot_rev_annual = df_studio_tot_rev_annual[df_studio_tot_rev_annual.year>2009]
df_studio_tot_rev_annual.reset_index(inplace = True)
df_studio_tot_rev_annual.head()
# Out:
#    index                                      title  id release_date  \
# 0      2                        10 Cloverfield Lane  54   2016-03-11
# 1     12                                  12 Strong  64   2018-01-19
# 2     13                           12 Years a Slave  18   2013-10-18
# 3     14                                  127 Hours   6   2010-11-05
# 4     16  13 Hours: The Secret Soldiers of Benghazi  30   2016-01-15
#
#    production_budget  domestic_gross  worldwide_gross  year studio  \
# 0          5000000.0      72082999.0      108286422.0  2016   Par.
# 1         35000000.0      45819713.0       71118378.0  2018     WB
# 2         20000000.0      56671993.0      181025343.0  2013   FoxS
# 3         18000000.0      18335230.0       60217171.0  2010   FoxS
# 4         50000000.0      52853219.0       69411370.0  2016   Par.
#
#    production_budget_m  domestic_gross_m  worldwide_gross_m  foreign_gross_m  \
# 0                  5.0              72.1              108.3             36.2
# 1                 35.0              45.8               71.1             25.3
# 2                 20.0              56.7              181.0            124.3
# 3                 18.0              18.3               60.2             41.9
# 4                 50.0              52.9               69.4             16.5
#
#    net_revenue_m    ROI   ROIpct  \
# 0          103.3  20.66  2065.73
# 1           36.1   1.03   103.20
# 2          161.0   8.05   805.13
# 3           42.2   2.35   234.54
# 4           19.4   0.39    38.82
#
#                                          title_yr  month_num month
# 0                        10 Cloverfield Lane-2016          3   Mar
# 1                                  12 Strong-2018          1   Jan
# 2                           12 Years a Slave-2013         10   Oct
# 3                                  127 Hours-2010         11   Nov
# 4  13 Hours: The Secret Soldiers of Benghazi-2016          1   Jan

# %%
# Create a subset
df_studio_tot_rev_annual = df_studio_tot_rev_annual.loc[:, ['studio', 'year', 'worldwide_gross_m']]
df_studio_tot_rev_annual.head()
# Out:
#   studio  year  worldwide_gross_m
# 0   Par.  2016              108.3
# 1     WB  2018               71.1
# 2   FoxS  2013              181.0
# 3   FoxS  2010               60.2
# 4   Par.  2016               69.4

# %%
# Separate top 6 studios from others
top6_studios = df_studio_tot_rev.sort_values('total_revenue', ascending = False).iloc[:6, 0].values

# %%
# top6_studios = ['BV', 'Uni.', 'Fox', 'WB', 'Sony', 'Par.']

df_top6_studios_tot_rev_annual = df_studio_tot_rev_annual.loc[df_studio_tot_rev_annual['studio'].isin(top6_studios)]
df_top6_studios_tot_rev_annual.head()
# Out:
#   studio  year  worldwide_gross_m
# 0   Par.  2016              108.3
# 1     WB  2018               71.1
# 4   Par.  2016               69.4
# 6   Uni.  2013              132.5
# 7   Sony  2012              202.8

# %%
# Group by multiple categories
df_top6_studios_tot_rev_annual = df_top6_studios_tot_rev_annual.groupby(['year', 'studio']).sum().unstack()
df_top6_studios_tot_rev_annual.tail()
# Out:
#        worldwide_gross_m
# studio                BV     Fox    Par.    Sony    Uni.      WB
# year
# 2014              3617.4  4648.6  2424.4  1518.0  1921.7  1513.5
# 2015              3524.7  3275.4  1088.2  2042.5  6419.0  1607.4
# 2016              6101.9  3482.1  1533.4  1018.2  3074.4  2690.9
# 2017              2816.7  2724.1  1020.3  2495.0  4150.2  3240.3
# 2018              6300.4  2306.5  1098.0  1254.6  3085.0  3982.9

# %%
from matplotlib import cm
viridis = cm.get_cmap('viridis', 6)

fig, ax = plt.subplots(figsize=(12,8))

df_top6_studios_tot_rev_annual.plot(kind='bar', stacked='True', color=viridis.colors, ax=ax)
ax.legend(['BV', 'Fox', 'Par.', 'Sony', 'Uni.', 'WB'], loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_title('Top Six Studios - Gross Revenue (Millions $)')
ax.set_ylabel('Millions $')
ax.set_xlabel('Year')
plt.show()

# %%
## QUESTIONS - PART 2: INDUSTRY TRENDS: IS MOVIE INDUSTRY PROFITABLE? Analysis w/o outliers and from year 2000 - present

# Create ROI df, remove NaN
df_roi = df_financials[df_financials['ROI'].notnull()]
display(df_financials.describe())
df_roi.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5780.000000       5.780000e+03    5.233000e+03     5.414000e+03
# mean     50.369723       3.159652e+07    4.626630e+07     9.769777e+07
# std      28.825690       4.181652e+07    7.030032e+07     1.788742e+08
# min       1.000000       1.100000e+03    3.880000e+02     2.600000e+01
# 25%      25.000000       5.000000e+06    4.299773e+06     7.002417e+06
# 50%      50.000000       1.700000e+07    2.199526e+07     3.331993e+07
# 75%      75.000000       4.000000e+07    5.759825e+07     1.044737e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#               year  production_budget_m  domestic_gross_m  worldwide_gross_m  \
# count  5780.000000          5780.000000       5233.000000        5414.000000
# mean   2003.965398            31.596003         46.265507          97.697211
# std      12.726243            41.816880         70.300669         178.874107
# min    1915.000000             0.000000          0.000000           0.000000
# 25%    2000.000000             5.000000          4.300000           7.000000
# 50%    2007.000000            17.000000         22.000000          33.300000
# 75%    2012.000000            40.000000         57.600000         104.475000
# max    2020.000000           425.000000        936.700000        2776.300000
#
#        foreign_gross_m  net_revenue_m          ROI         ROIpct    month_num
# count      5233.000000    5414.000000  5414.000000    5414.000000  5780.000000
# mean         54.506191      64.383487     4.109852     410.989073     7.051384
# std         117.793693     149.871371    30.468579    3046.861304     3.480491
# min           0.000000    -200.200000    -1.000000    -100.000000     1.000000
# 25%           0.000000      -1.900000    -0.300000     -29.902500     4.000000
# 50%           9.400000      11.900000     0.880000      88.480000     7.000000
# 75%          53.300000      67.400000     2.967500     296.537500    10.000000
# max        2015.800000    2351.300000  1799.000000  179900.000000    12.000000
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5414.000000       5.414000e+03    5.233000e+03     5.414000e+03
# mean     50.225896       3.331407e+07    4.626630e+07     9.769777e+07
# std      28.767517       4.248916e+07    7.030032e+07     1.788742e+08
# min       1.000000       1.100000e+03    3.880000e+02     2.600000e+01
# 25%      25.000000       6.000000e+06    4.299773e+06     7.002417e+06
# 50%      50.000000       1.900000e+07    2.199526e+07     3.331993e+07
# 75%      75.000000       4.200000e+07    5.759825e+07     1.044737e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#               year  production_budget_m  domestic_gross_m  worldwide_gross_m  \
# count  5414.000000          5414.000000       5233.000000        5414.000000
# mean   2003.598448            33.313724         46.265507          97.697211
# std      12.547909            42.489400         70.300669         178.874107
# min    1915.000000             0.000000          0.000000           0.000000
# 25%    1999.000000             6.000000          4.300000           7.000000
# 50%    2006.000000            19.000000         22.000000          33.300000
# 75%    2012.000000            42.000000         57.600000         104.475000
# max    2019.000000           425.000000        936.700000        2776.300000
#
#        foreign_gross_m  net_revenue_m          ROI         ROIpct    month_num
# count      5233.000000    5414.000000  5414.000000    5414.000000  5414.000000
# mean         54.506191      64.383487     4.109852     410.989073     6.978020
# std         117.793693     149.871371    30.468579    3046.861304     3.444162
# min           0.000000    -200.200000    -1.000000    -100.000000     1.000000
# 25%           0.000000      -1.900000    -0.300000     -29.902500     4.000000
# 50%           9.400000      11.900000     0.880000      88.480000     7.000000
# 75%          53.300000      67.400000     2.967500     296.537500    10.000000
# max        2015.800000    2351.300000  1799.000000  179900.000000    12.000000

# %%
# Outlier detection
min_roi_threshold, max_roi_threshold = df_roi['ROI'].quantile([0.00, 0.90]).round(2)
min_roi_threshold, max_roi_threshold
# Out:
# (-1.0, 7.16)

# %%
df_roi[df_roi['ROI'] > max_roi_threshold]
# Out:
#                              title  id release_date  production_budget  \
# 2              10 Cloverfield Lane  54   2016-03-11          5000000.0
# 13                12 Years a Slave  18   2013-10-18         20000000.0
# 30                        20 Dates   9   1999-02-26            66000.0
# 33    20,000 Leagues Under the Sea  15   1916-12-24           200000.0
# 37         2016: Obamaâs America  13   2012-07-13          2500000.0
# ...                            ...  ..          ...                ...
# 5739           You Only Live Twice  54   1967-06-13          9500000.0
# 5741                   You're Next  17   2013-08-23          1000000.0
# 5745            Young Frankenstein  84   1974-12-15          2800000.0
# 5749          Your Sister's Sister  73   2012-06-15           120000.0
# 5773                         [Rec]  82   2009-07-14          2100000.0
#
#       domestic_gross  worldwide_gross  year studio  production_budget_m  \
# 2         72082999.0      108286422.0  2016   Par.                  5.0
# 13        56671993.0      181025343.0  2013   FoxS                 20.0
# 30          541636.0         602920.0  1999    NaN                  0.1
# 33         8000000.0        8000000.0  1916    NaN                  0.2
# 37        33349941.0       33349941.0  2012    NaN                  2.5
# ...              ...              ...   ...    ...                  ...
# 5739      43100000.0      111600000.0  1967    NaN                  9.5
# 5741      18494006.0       26887177.0  2013    LGF                  1.0
# 5745      86300000.0       86300000.0  1974    NaN                  2.8
# 5749       1597486.0        3090593.0  2012    IFC                  0.1
# 5773             NaN       23266821.0  2009    NaN                  2.1
#
#       domestic_gross_m  worldwide_gross_m  foreign_gross_m  net_revenue_m  \
# 2                 72.1              108.3             36.2          103.3
# 13                56.7              181.0            124.3          161.0
# 30                 0.5                0.6              0.1            0.5
# 33                 8.0                8.0              0.0            7.8
# 37                33.3               33.3              0.0           30.8
# ...                ...                ...              ...            ...
# 5739              43.1              111.6             68.5          102.1
# 5741              18.5               26.9              8.4           25.9
# 5745              86.3               86.3              0.0           83.5
# 5749               1.6                3.1              1.5            3.0
# 5773               NaN               23.3              NaN           21.2
#
#         ROI   ROIpct                           title_yr  month_num month
# 2     20.66  2065.73           10 Cloverfield Lane-2016          3   Mar
# 13     8.05   805.13              12 Years a Slave-2013         10   Oct
# 30     8.14   813.52                      20 Dates-1999          2   Feb
# 33    39.00  3900.00  20,000 Leagues Under the Sea-1916         12   Dec
# 37    12.34  1234.00       2016: Obamaâs America-2012          7   Jul
# ...     ...      ...                                ...        ...   ...
# 5739  10.75  1074.74           You Only Live Twice-1967          6   Jun
# 5741  25.89  2588.72                   You're Next-2013          8   Aug
# 5745  29.82  2982.14            Young Frankenstein-1974         12   Dec
# 5749  24.75  2475.49          Your Sister's Sister-2012          6   Jun
# 5773  10.08  1007.94                         [Rec]-2009          7   Jul
#
# [541 rows x 18 columns]

# %%
# new DF without ROI outliers and with movies from year 2000 - present
df_roi = df_roi[(df_roi['ROI'] < max_roi_threshold) & 
                       (df_roi['ROI'] > min_roi_threshold) & 
                       (df_roi['year'] >= 2000)]
display(df_roi.sort_values('ROI', ascending = False).head(10))
# Out:
#                                                   title  id release_date  \
# 103                                   A Dogâs Purpose  86   2017-01-27
# 4425                                        The Descent   1   2006-08-04
# 4790  The Lord of the Rings: The Fellowship of the Ring  43   2001-12-19
# 4757                            The Legend of God's Gun  37   2008-07-18
# 5074                                         The Signal  19   2008-02-22
# 2055              Hotel Transylvania 3: Summer Vacation  77   2018-07-13
# 1800                          Good Night, and Good Luck  98   2005-10-07
# 3992                          Star Wars: The Clone Wars  32   2008-08-15
# 3067                                      Nochnoy dozor  70   2006-02-17
# 5673                                      Winter's Bone   8   2010-06-11
#
#       production_budget  domestic_gross  worldwide_gross  year studio  \
# 103          25000000.0      64321890.0      203671625.0  2017    NaN
# 4425          7000000.0      26024456.0       57051053.0  2006    NaN
# 4790        109000000.0     315544750.0      887210985.0  2001    NaN
# 4757            30000.0        243768.0         243768.0  2008    NaN
# 5074            50000.0        251150.0         406299.0  2008    NaN
# 2055         65000000.0     167500092.0      527079962.0  2018   Sony
# 1800          7000000.0      31501218.0       56586901.0  2005    NaN
# 3992          8500000.0      35161554.0       68695443.0  2008    NaN
# 3067          4200000.0       1502188.0       33913542.0  2006    NaN
# 5673          2000000.0       6531503.0       16131551.0  2010  RAtt.
#
#       production_budget_m  domestic_gross_m  worldwide_gross_m  \
# 103                  25.0              64.3              203.7
# 4425                  7.0              26.0               57.1
# 4790                109.0             315.5              887.2
# 4757                  0.0               0.2                0.2
# 5074                  0.0               0.3                0.4
# 2055                 65.0             167.5              527.1
# 1800                  7.0              31.5               56.6
# 3992                  8.5              35.2               68.7
# 3067                  4.2               1.5               33.9
# 5673                  2.0               6.5               16.1
#
#       foreign_gross_m  net_revenue_m   ROI  ROIpct  \
# 103             139.4          178.7  7.15  714.69
# 4425             31.1           50.1  7.15  715.02
# 4790            571.7          778.2  7.14  713.96
# 4757              0.0            0.2  7.13  712.56
# 5074              0.1            0.4  7.13  712.60
# 2055            359.6          462.1  7.11  710.89
# 1800             25.1           49.6  7.08  708.38
# 3992             33.5           60.2  7.08  708.18
# 3067             32.4           29.7  7.07  707.47
# 5673              9.6           14.1  7.07  706.58
#
#                                                title_yr  month_num month
# 103                              A Dogâs Purpose-2017          1   Jan
# 4425                                   The Descent-2006          8   Aug
# 4790  The Lord of the Rings: The Fellowship of the R...         12   Dec
# 4757                       The Legend of God's Gun-2008          7   Jul
# 5074                                    The Signal-2008          2   Feb
# 2055         Hotel Transylvania 3: Summer Vacation-2018          7   Jul
# 1800                     Good Night, and Good Luck-2005         10   Oct
# 3992                     Star Wars: The Clone Wars-2008          8   Aug
# 3067                                 Nochnoy dozor-2006          2   Feb
# 5673                                 Winter's Bone-2010          6   Jun

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.hist(df_roi['ROI'], bins='auto', alpha = 0.5)
ax.set_title('Distribution of ROI')
ax.set_xlabel('ROI')
ax.set_ylabel('Number of Movies')
ax.axvline(df_roi['ROI'].mean(), color = 'black')
ax.axvline(df_roi['ROI'].median(), color = 'red')

# %%
display(df_roi.ROI.apply(['mean', 'median', 'std']))
# Out:
# mean      1.115363
# median    0.630000
# std       1.873178
# Name: ROI, dtype: float64

# %%
df_roi.boxplot(column=['ROI'])

# %%
#create new ROI buckets column 
def ROI_buckets(r):
    if r < 0: 
        return 'Not profitable'
    if r <= 1 : 
        return '0 - 100%'
    elif r <= 2: 
        return '100% - 200%'
    elif r <= 3: 
        return '200% - 300%'
    elif r <= 4: 
        return '300% - 400%'
    elif r <= 5: 
        return '400% - 500%'
    elif r <= 6: 
        return '500% - 600%'    
    elif r <= 7:
        return '600% - 700&'
    elif r <= 8:
        return '700% - 800%'
    else: 
        return 'Other'

df_roi['ROI_buckets'] = df_roi['ROI'].apply(ROI_buckets)
display(df_roi.head(10))
df_roi.info()
# Out:
#                                         title  id release_date  \
# 1                        (500) Days of Summer  55   2009-07-17
# 5                                 10,000 B.C.  51   2008-03-07
# 6                              102 Dalmatians   6   2000-11-22
# 7                                 10th & Wolf  32   2006-08-18
# 11                                  12 Rounds  37   2009-03-27
# 12                                  12 Strong  64   2018-01-19
# 14                                  127 Hours   6   2010-11-05
# 15                             13 Going On 30  96   2004-04-23
# 16  13 Hours: The Secret Soldiers of Benghazi  30   2016-01-15
# 17                                    13 Sins  51   2014-04-18
#
#     production_budget  domestic_gross  worldwide_gross  year studio  \
# 1           7500000.0      32425665.0       34439060.0  2009    NaN
# 5         105000000.0      94784201.0      269065678.0  2008    NaN
# 6          85000000.0      66941559.0       66941559.0  2000    NaN
# 7           8000000.0         54702.0         143782.0  2006    NaN
# 11         20000000.0      12234694.0       17306648.0  2009    NaN
# 12         35000000.0      45819713.0       71118378.0  2018     WB
# 14         18000000.0      18335230.0       60217171.0  2010   FoxS
# 15         37000000.0      57139723.0       97658712.0  2004    NaN
# 16         50000000.0      52853219.0       69411370.0  2016   Par.
# 17          4000000.0          9134.0          47552.0  2014   RTWC
#
#     production_budget_m  domestic_gross_m  worldwide_gross_m  foreign_gross_m  \
# 1                   7.5              32.4               34.4              2.0
# 5                 105.0              94.8              269.1            174.3
# 6                  85.0              66.9               66.9              0.0
# 7                   8.0               0.1                0.1              0.0
# 11                 20.0              12.2               17.3              5.1
# 12                 35.0              45.8               71.1             25.3
# 14                 18.0              18.3               60.2             41.9
# 15                 37.0              57.1               97.7             40.6
# 16                 50.0              52.9               69.4             16.5
# 17                  4.0               0.0                0.0              0.0
#
#     net_revenue_m   ROI  ROIpct  \
# 1            26.9  3.59  359.19
# 5           164.1  1.56  156.25
# 6           -18.1 -0.21  -21.25
# 7            -7.9 -0.98  -98.20
# 11           -2.7 -0.13  -13.47
# 12           36.1  1.03  103.20
# 14           42.2  2.35  234.54
# 15           60.7  1.64  163.94
# 16           19.4  0.39   38.82
# 17           -4.0 -0.99  -98.81
#
#                                           title_yr  month_num month  \
# 1                        (500) Days of Summer-2009          7   Jul
# 5                                 10,000 B.C.-2008          3   Mar
# 6                              102 Dalmatians-2000         11   Nov
# 7                                 10th & Wolf-2006          8   Aug
# 11                                  12 Rounds-2009          3   Mar
# 12                                  12 Strong-2018          1   Jan
# 14                                  127 Hours-2010         11   Nov
# 15                             13 Going On 30-2004          4   Apr
# 16  13 Hours: The Secret Soldiers of Benghazi-2016          1   Jan
# 17                                    13 Sins-2014          4   Apr
#
#        ROI_buckets
# 1      300% - 400%
# 5      100% - 200%
# 6   Not profitable
# 7   Not profitable
# 11  Not profitable
# 12     100% - 200%
# 14     200% - 300%
# 15     100% - 200%
# 16        0 - 100%
# 17  Not profitable
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3677 entries, 1 to 5781
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                3677 non-null   object
#  1   id                   3677 non-null   int64
#  2   release_date         3677 non-null   datetime64[ns]
#  3   production_budget    3677 non-null   float64
#  4   domestic_gross       3517 non-null   float64
#  5   worldwide_gross      3677 non-null   float64
#  6   year                 3677 non-null   int64
#  7   studio               1106 non-null   object
#  8   production_budget_m  3677 non-null   float64
#  9   domestic_gross_m     3517 non-null   float64
#  10  worldwide_gross_m    3677 non-null   float64
#  11  foreign_gross_m      3517 non-null   float64
#  12  net_revenue_m        3677 non-null   float64
#  13  ROI                  3677 non-null   float64
#  14  ROIpct               3677 non-null   float64
#  15  title_yr             3677 non-null   object
#  16  month_num            3677 non-null   int64
#  17  month                3677 non-null   object
#  18  ROI_buckets          3677 non-null   object
# dtypes: datetime64[ns](1), float64(10), int64(3), object(5)
# memory usage: 574.5+ KB

# %%
#Distribution of ROI by year
df_roi_yr = df_roi.groupby('year')['ROI_buckets'].value_counts(normalize = True)
df_roi_yr
# Out:
# year  ROI_buckets
# 2000  Not profitable    0.352273
#       0 - 100%          0.255682
#       100% - 200%       0.159091
#       300% - 400%       0.079545
#       200% - 300%       0.062500
#                           ...
# 2019  100% - 200%       0.090909
#       300% - 400%       0.068182
#       500% - 600%       0.045455
#       400% - 500%       0.022727
#       600% - 700&       0.022727
# Name: ROI_buckets, Length: 168, dtype: float64

# %%
# Analysis of ROI of movies in 90th percentile by ROI and after year 2000 (3,676 total movies)
df_yr_median = df_roi.groupby(['year']).agg(['median'])
df_yr_median
# Out:
#          id production_budget domestic_gross worldwide_gross  \
#      median            median         median          median
# year
# 2000   51.0        23500000.0     20752058.5      32831338.0
# 2001   53.0        25000000.0     25288103.0      29406132.0
# 2002   49.5        21000000.0     19119407.0      28643729.5
# 2003   43.0        20000000.0     19480739.0      27676370.0
# 2004   50.5        26000000.0     21092751.0      34607966.0
# 2005   47.0        25000000.0     20370488.5      38273443.0
# 2006   47.5        17750000.0     16099104.5      27834762.5
# 2007   46.0        20000000.0     15036130.5      30261293.0
# 2008   50.0        20000000.0     15298133.0      30894247.0
# 2009   45.0        20000000.0     20727036.5      36736304.0
# 2010   47.0        18000000.0     13601929.0      25941437.0
# 2011   52.0        25000000.0     21302340.0      38070192.0
# 2012   52.0        24200000.0     19106196.0      41294674.0
# 2013   49.5        22000000.0     22537881.0      47259977.0
# 2014   47.5        19000000.0     25167749.0      35444612.5
# 2015   47.0        20000000.0     17766658.0      30725430.5
# 2016   47.0        22750000.0     21587519.0      39867403.5
# 2017   51.0        29200000.0     30014534.0      47879572.0
# 2018   52.0        32000000.0     40054284.0      66295121.0
# 2019   51.5        40000000.0     35095904.0      42218261.5
#
#      production_budget_m domestic_gross_m worldwide_gross_m foreign_gross_m  \
#                   median           median            median          median
# year
# 2000               23.50            20.75             32.85            7.10
# 2001               25.00            25.30             29.40            4.90
# 2002               21.00            19.15             28.65            4.90
# 2003               20.00            19.50             27.65            8.80
# 2004               26.00            21.10             34.60           10.35
# 2005               25.00            20.35             38.25           15.10
# 2006               17.75            16.10             27.85            9.65
# 2007               20.00            15.05             30.30           16.75
# 2008               20.00            15.30             30.90           11.60
# 2009               20.00            20.70             36.70           19.65
# 2010               18.00            13.60             25.90           12.95
# 2011               25.00            21.30             38.05           16.40
# 2012               24.20            19.10             41.30           18.50
# 2013               22.00            22.50             47.25           25.60
# 2014               19.00            25.15             35.45           12.35
# 2015               20.00            17.80             30.75           15.90
# 2016               22.75            21.60             39.85           21.70
# 2017               29.20            30.00             47.90           29.00
# 2018               32.00            40.05             66.30           26.25
# 2019               40.00            35.10             42.20           16.00
#
#      net_revenue_m    ROI   ROIpct month_num
#             median median   median    median
# year
# 2000          3.90  0.430   42.905       7.0
# 2001          5.90  0.480   47.790       8.0
# 2002          6.00  0.375   37.625       7.0
# 2003          6.80  0.405   40.205       7.0
# 2004          3.65  0.390   38.800       7.0
# 2005          7.00  0.390   39.015       7.0
# 2006          8.20  0.465   46.690       7.0
# 2007          5.20  0.350   34.670       8.0
# 2008          9.70  0.640   63.960       8.0
# 2009          9.30  0.645   64.565       8.0
# 2010          7.70  0.530   53.160       7.0
# 2011         12.85  0.765   76.660       7.0
# 2012         13.40  0.820   82.190       7.0
# 2013         19.85  1.115  111.345       7.0
# 2014         13.85  0.895   89.115       7.0
# 2015          8.10  0.390   38.810       7.0
# 2016         15.95  0.945   94.200       7.0
# 2017         22.70  1.230  122.990       7.0
# 2018         33.90  1.190  119.200       7.0
# 2019         14.45  0.375   37.360       3.5

# %%
df_yr_median_roi = df_yr_median['ROIpct']
df_yr_median_roi = df_yr_median_roi.rename(columns={"median": "ROIpct_median"})
df_yr_median_roi.columns
# Out:
# Index(['ROIpct_median'], dtype='object')

# %%
df_yr_median_roi.head()
# Out:
#       ROIpct_median
# year
# 2000         42.905
# 2001         47.790
# 2002         37.625
# 2003         40.205
# 2004         38.800

# %%
# Graph industry median and mean ROI 

fig, ax = plt.subplots(figsize=(10,8))

ROIpct_yr_median = df_yr_median_roi.ROIpct_median
yr = df_yr_median_roi.index

ax.bar(yr, ROIpct_yr_median, width=0.8, color = 'navy')
ax.set_title('Median ROI - Movies in 90th percentile')
ax.set_xlabel('Year')
ax.set_ylabel('Median ROI (%)')

ax.set_xticks(np.arange(2000,2020, 1))
ax.set_yticks(np.arange(0,130,10))

plt.style.use('ggplot')
plt.tight_layout()
plt.show()

# %%
# Prepare data for stacked 100% bar chart.
# Create df grouped by year and count of ROI buckets. Convert count of ROI buckets to percent of total count.
df_roi_pct = ((df_roi.groupby(['year', 'ROI_buckets'])['ROI_buckets'].count()/df_roi.groupby(['year'])['ROI_buckets'].count()))*100
display(df_roi_pct.tail(8))
# Out:
# year  ROI_buckets
# 2019  0 - 100%          25.000000
#       100% - 200%        9.090909
#       200% - 300%       15.909091
#       300% - 400%        6.818182
#       400% - 500%        2.272727
#       500% - 600%        4.545455
#       600% - 700&        2.272727
#       Not profitable    34.090909
# Name: ROI_buckets, dtype: float64

# %%
#Set color map to viridis and select nine colors
viridis = cm.get_cmap('viridis', 9)

#Create stacked bar chart
ax = df_roi_pct.unstack().plot.bar(stacked = True, figsize=(14,10), color=viridis.colors)

#Set title, x-label, y-label
ax.set_title('ROI - Movies in 90th percentile', fontsize = 18)
ax.set_xlabel('Year', fontsize = 14)
ax.set_ylabel('Percent of movies (%)', fontsize = 14)

#Set y-axis ticks: min, max, interval
ax.yaxis.set_ticks(np.arange(0, 110, 10))

#Set tick marks on right side
ax.tick_params(labeltop=False, labelright=True)

# Reverse legend order and set legend location
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='center left', bbox_to_anchor=(1.05,0.5))

plt.show()

# %%
sns.regplot(x='ROIpct',y='production_budget',data=df_roi)

# %%
## Explore distributions and relationships
df_roi.plot.scatter(x = 'ROIpct',
                       y = 'production_budget', 
                       c = 'blue', 
                   figsize = (10,6))

from scipy.stats import linregress
x = df_roi.ROIpct
y = df_roi.production_budget
stats = linregress(x, y)

m = stats.slope
b = stats.intercept

# Set the linewidth on the regression line to 3px
plt.plot(x, m * x + b, color="red", linewidth=3)

plt.title('Relationship between ROI and Production Budget', fontsize = 12)
plt.xlabel('ROI (%)', fontsize = 12)
#plt.ylabel('Production Budget ($)', fontsize = 12)

plt.show()

# %%
df_roi.groupby('ROI_buckets').production_budget_m.median().plot.bar(figsize=(10,6))
plt.title('Median Production Budget (Millions $)', fontsize = 12)
plt.xlabel('ROI', fontsize = 12)
plt.yticks(np.arange(0, 45, 5))
#plt.ylabel('Median Production Budget ($)', fontsize = 12)
plt.show()

# %%
df_yr_median.reset_index(inplace = True)
df_yr_median.head()
# Out:
#    year     id production_budget domestic_gross worldwide_gross  \
#         median            median         median          median
# 0  2000   51.0        23500000.0     20752058.5      32831338.0
# 1  2001   53.0        25000000.0     25288103.0      29406132.0
# 2  2002   49.5        21000000.0     19119407.0      28643729.5
# 3  2003   43.0        20000000.0     19480739.0      27676370.0
# 4  2004   50.5        26000000.0     21092751.0      34607966.0
#
#   production_budget_m domestic_gross_m worldwide_gross_m foreign_gross_m  \
#                median           median            median          median
# 0                23.5            20.75             32.85            7.10
# 1                25.0            25.30             29.40            4.90
# 2                21.0            19.15             28.65            4.90
# 3                20.0            19.50             27.65            8.80
# 4                26.0            21.10             34.60           10.35
#
#   net_revenue_m    ROI  ROIpct month_num
#          median median  median    median
# 0          3.90  0.430  42.905       7.0
# 1          5.90  0.480  47.790       8.0
# 2          6.00  0.375  37.625       7.0
# 3          6.80  0.405  40.205       7.0
# 4          3.65  0.390  38.800       7.0

# %%
yr = df_yr_median[['year']]
worldwide_gross = df_yr_median[['worldwide_gross_m']]
production_budget = df_yr_median[['production_budget_m']]

df_roi_comp = df_yr_median[['year','worldwide_gross_m','production_budget_m', 'domestic_gross_m', 'foreign_gross_m']]
df_roi_comp = df_roi_comp.rename(columns = {'year':'Year', 'worldwide_gross_m': 'Gross Revenue', 'production_budget_m': 'Production Budget', 'domestic_gross_m': 'Domestic Gross', 'foreign_gross_m': 'Foreign Gross'})
df_roi_comp.head()
# Out:
#    Year Gross Revenue Production Budget Domestic Gross Foreign Gross
#                median            median         median        median
# 0  2000         32.85              23.5          20.75          7.10
# 1  2001         29.40              25.0          25.30          4.90
# 2  2002         28.65              21.0          19.15          4.90
# 3  2003         27.65              20.0          19.50          8.80
# 4  2004         34.60              26.0          21.10         10.35

# %%
# Graph gross revenue and production budget by year

df_roi_comp.plot(x="Year", y=["Production Budget", "Gross Revenue"], kind="bar", figsize=(8,8))
plt.title('Gross Revenue and Production Budget (Millions $)', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.yticks(np.arange (0, 80, 5))

plt.legend()

# %%
# Breakdown of domestic and foreign gross revenue

df_roi_comp.plot(x="Year", y=["Domestic Gross", "Foreign Gross"], figsize=(12,8))
plt.title('Gross Revenue and Domestic Revenue (Millions $)', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.xticks(np.arange (2000, 2020, 1))
plt.yticks(np.arange (0, 50, 5))
plt.legend()
plt.show()

# %%
df_roi_comp_from2014 = df_yr_median[['year','worldwide_gross_m','production_budget_m']][df_yr_median['year']>=2014]
df_roi_comp_from2014.head()
# Out:
#     year worldwide_gross_m production_budget_m
#                     median              median
# 14  2014             35.45               19.00
# 15  2015             30.75               20.00
# 16  2016             39.85               22.75
# 17  2017             47.90               29.20
# 18  2018             66.30               32.00

# %%
df_roi_comp_from2014.plot.scatter(x = 'worldwide_gross_m',
                       y = 'production_budget_m', 
                       c = 'blue', 
                   figsize = (10,6))

from scipy.stats import linregress
x = df_roi_comp_from2014.worldwide_gross_m
y = df_roi_comp_from2014.production_budget_m

m = stats.slope
b = stats.intercept

plt.title('Relationship between Gross Revenue and Production Budget', fontsize = 12)
#plt.xlabel('Gross Revenue', fontsize = 12)
#plt.ylabel('Production Budget', fontsize = 12)

plt.show()

# %%
## ROI and year movie released
df_yr_median.plot.bar(x = 'year', y = 'ROIpct', 
                       color = 'navy', figsize = (10,8), legend=None)

plt.title('Median ROI by Year (%)', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.yticks(np.arange (0, 160, 20))

plt.show()

# %%
#Distribution of ROI by month
df_roi_mo_median = df_roi.groupby(['month_num']).agg(['median'])
df_roi_mo_median.head()
# Out:
#               id production_budget domestic_gross worldwide_gross   year  \
#           median            median         median          median median
# month_num
# 1           48.5        22500000.0     19719930.0      36171654.0   2010
# 2           48.0        24000000.0     25288103.0      43793995.0   2009
# 3           50.5        20000000.0     23514247.0      35409982.0   2009
# 4           49.0        20000000.0     16008272.0      23910786.0   2009
# 5           48.5        27000000.0     28638916.0      38159253.0   2009
#
#           production_budget_m domestic_gross_m worldwide_gross_m  \
#                        median           median            median
# month_num
# 1                        22.5             19.7             36.15
# 2                        24.0             25.3             43.80
# 3                        20.0             23.5             35.40
# 4                        20.0             16.0             23.90
# 5                        27.0             28.6             38.20
#
#           foreign_gross_m net_revenue_m    ROI  ROIpct
#                    median        median median  median
# month_num
# 1                    13.3         11.10  0.595  59.625
# 2                    14.7         15.70  0.765  76.335
# 3                    13.7         11.85  0.530  52.830
# 4                     6.8          4.75  0.360  36.135
# 5                    15.2         14.00  0.790  78.635

# %%
df_roi_mo_median.reset_index(inplace = True)

# %%
df_roi_mo_median['month'] = pd.to_datetime(df_roi_mo_median['month_num'], format='%m').dt.month_name().str.slice(stop=3)
df_roi_mo_median.head()
# Out:
#   month_num     id production_budget domestic_gross worldwide_gross   year  \
#             median            median         median          median median
# 0         1   48.5        22500000.0     19719930.0      36171654.0   2010
# 1         2   48.0        24000000.0     25288103.0      43793995.0   2009
# 2         3   50.5        20000000.0     23514247.0      35409982.0   2009
# 3         4   49.0        20000000.0     16008272.0      23910786.0   2009
# 4         5   48.5        27000000.0     28638916.0      38159253.0   2009
#
#   production_budget_m domestic_gross_m worldwide_gross_m foreign_gross_m  \
#                median           median            median          median
# 0                22.5             19.7             36.15            13.3
# 1                24.0             25.3             43.80            14.7
# 2                20.0             23.5             35.40            13.7
# 3                20.0             16.0             23.90             6.8
# 4                27.0             28.6             38.20            15.2
#
#   net_revenue_m    ROI  ROIpct month
#          median median  median
# 0         11.10  0.595  59.625   Jan
# 1         15.70  0.765  76.335   Feb
# 2         11.85  0.530  52.830   Mar
# 3          4.75  0.360  36.135   Apr
# 4         14.00  0.790  78.635   May

# %%
df_roi_mo_median.plot.bar(x='month', y='ROIpct', color = 'green', figsize=(10,6), legend=None)
plt.title('Median ROI by Month (%)', fontsize = 12)
plt.xlabel('Month', fontsize = 12)
plt.yticks(np.arange (0, 120, 20))

plt.show()

# %%
# Which studios produce high ROI movies?

# %%
df_roi['studio'].nunique()
# Out:
# 97

# %%
# Create new df - top studios by ROI
df_studio_roi = df_roi.dropna(subset=['studio'])
df_studio_roi.head()
# Out:
#                                         title  id release_date  \
# 12                                  12 Strong  64   2018-01-19
# 14                                  127 Hours   6   2010-11-05
# 16  13 Hours: The Secret Soldiers of Benghazi  30   2016-01-15
# 17                                    13 Sins  51   2014-04-18
# 29                                     2 Guns  39   2013-08-02
#
#     production_budget  domestic_gross  worldwide_gross  year studio  \
# 12         35000000.0      45819713.0       71118378.0  2018     WB
# 14         18000000.0      18335230.0       60217171.0  2010   FoxS
# 16         50000000.0      52853219.0       69411370.0  2016   Par.
# 17          4000000.0          9134.0          47552.0  2014   RTWC
# 29         61000000.0      75612460.0      132493015.0  2013   Uni.
#
#     production_budget_m  domestic_gross_m  worldwide_gross_m  foreign_gross_m  \
# 12                 35.0              45.8               71.1             25.3
# 14                 18.0              18.3               60.2             41.9
# 16                 50.0              52.9               69.4             16.5
# 17                  4.0               0.0                0.0              0.0
# 29                 61.0              75.6              132.5             56.9
#
#     net_revenue_m   ROI  ROIpct  \
# 12           36.1  1.03  103.20
# 14           42.2  2.35  234.54
# 16           19.4  0.39   38.82
# 17           -4.0 -0.99  -98.81
# 29           71.5  1.17  117.20
#
#                                           title_yr  month_num month  \
# 12                                  12 Strong-2018          1   Jan
# 14                                  127 Hours-2010         11   Nov
# 16  13 Hours: The Secret Soldiers of Benghazi-2016          1   Jan
# 17                                    13 Sins-2014          4   Apr
# 29                                     2 Guns-2013          8   Aug
#
#        ROI_buckets
# 12     100% - 200%
# 14     200% - 300%
# 16        0 - 100%
# 17  Not profitable
# 29     100% - 200%

# %%
df_studio_roi = df_roi.sort_values('ROIpct', ascending = False)
df_studio_roi = df_roi.groupby('studio')['ROIpct'].agg(['median'])
df_studio_roi.reset_index(inplace = True)

# %%
df_studio_roi.rename(columns = {'median':'ROIpct_median'}, inplace = True)

# %%
df_studio_roi.sort_values('ROIpct_median', ascending = False)
# Out:
#     studio  ROIpct_median
# 57    Neon        389.070
# 49    MBox        327.185
# 4   Affirm        303.845
# 18      CJ        287.370
# 81  Strand        287.280
# ..     ...            ...
# 40     IVP        -94.870
# 5      Alc        -98.390
# 10     BBC        -98.680
# 30   First        -99.050
# 43      KE        -99.470
#
# [97 rows x 2 columns]

# %%
df_studio_roi_top25 = df_studio_roi.sort_values('ROIpct_median', ascending = False).head(25)
df_studio_roi_top50 = df_studio_roi.sort_values('ROIpct_median', ascending = False).head(50)
df_studio_positiveROI = df_studio_roi[df_studio_roi.ROIpct_median>100].sort_values('ROIpct_median', ascending = False)
#df_financials[df_financials.worldwide_gross_m >= 8.938658e+02].sort_values('worldwide_gross_m', ascending = False)

display(df_studio_roi_top25.shape)
display(df_studio_roi_top50.shape)
display(df_studio_positiveROI.shape)
# Out:
# (25, 2)
# (50, 2)
# (35, 2)

# %%
df_studio_positiveROI.plot.barh(x='studio', y='ROIpct_median', color = 'navy', figsize=(10,8), legend=None)

plt.title('Top Studios by ROI')
plt.xlabel('Median ROI (%)')
plt.ylabel=('Studio')

plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
## QUESTIONS - PART 3: WHAT IS THE BUSINESS MODEL OF TOP STUDIOS? (Movie runtime, genre)

# %%
# Explore df4 and df8

# %%
df4.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
df8.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
df8.studio.value_counts().nlargest(25)
# Out:
# Universal Pictures          35
# Paramount Pictures          27
# 20th Century Fox            26
# Sony Pictures Classics      22
# Warner Bros. Pictures       21
# Sony Pictures               16
# Columbia Pictures           10
# New Line Cinema             10
# IFC Films                    9
# Warner Bros.                 8
# Miramax Films                8
# Fox Searchlight Pictures     7
# MGM                          7
# Magnolia Pictures            7
# Walt Disney Pictures         6
# Roadside Attractions         6
# The Weinstein Company        6
# Focus Features               6
# Lionsgate Films              6
# Lions Gate Films             6
# Paramount Vantage            5
# Buena Vista Pictures         5
# Summit Entertainment         5
# Fox Searchlight              4
# Open Road Films              3
# Name: studio, dtype: int64

# %%
# Explore genres, runtimes for top revenue grossing studios

# %%
### .isin(top_6)
#Create new df - studios' business model (genres, runtime for top revenue grossing studios)
df_topstudio_model = df8[(df8['studio'] == 'Universal Pictures') | 
                         (df8['studio'] == 'Paramount Pictures') |
                         (df8['studio'] == '20th Century Fox') |
                         (df8['studio'] == 'Sony Pictures Classics') |
                         (df8['studio'] == 'Warner Bros. Pictures') |
                        (df8['studio'] == 'Warner Bros.') |
                        (df8['studio'] =='Buenva Vista Pictures') |
                        (df8['studio'] == 'Walt Disney Pictures')].copy()

df_topstudio_model.head()
# Out:
#     id                                           synopsis rating  \
# 5    8  The year is 1942. As the Allies unite overseas...     PG
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
# 24  34  Director John Woo brings Hong Kong-style marti...  PG-13
#
#                                                 genre          director  \
# 5                               Drama|Kids and Family       Jay Russell
# 6                                              Comedy       Jake Kasdan
# 7                                               Drama      Ray Lawrence
# 18  Action and Adventure|Drama|Science Fiction and...  Carl Erik Rinsch
# 24          Action and Adventure|Mystery and Suspense          John Woo
#
#                                                writer  theater_date  \
# 5                                     Gail Gilchriest   Mar 3, 2000
# 6                                          Mike White  Jan 11, 2002
# 7                    Raymond Carver|Beatrix Christian  Apr 27, 2006
# 18                         Chris Morgan|Hossein Amini  Dec 25, 2013
# 24  William Goldman|John Logan|David Marconi|Micha...  Dec 31, 2000
#
#         dvd_date currency  box_office      runtime                  studio
# 5   Jul 11, 2000      NaN         NaN   95 minutes   Warner Bros. Pictures
# 6   Jun 18, 2002        $  41,032,915   82 minutes      Paramount Pictures
# 7    Oct 2, 2007        $     224,114  123 minutes  Sony Pictures Classics
# 18   Apr 1, 2014        $  20,518,224  127 minutes      Universal Pictures
# 24   Nov 7, 2000      NaN         NaN  123 minutes      Paramount Pictures

# %%
# Clean up studio names
df_topstudio_model['studio'] = df_topstudio_model['studio'].replace({'Warner Bros.' : 'Warner Bros. Pictures'})
df_topstudio_model['studio'] = df_topstudio_model['studio'].replace({'Walt Disney Pictures' : 'Buena Vista Pictures'})
df_topstudio_model.head(10)
# Out:
#     id                                           synopsis rating  \
# 5    8  The year is 1942. As the Allies unite overseas...     PG
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
# 24  34  Director John Woo brings Hong Kong-style marti...  PG-13
# 51  65  A classic Disney fairytale collides with moder...     PG
# 53  67  After a mysterious, lost night on their honeym...      R
# 56  70  Indiana Jones (Harrison Ford) is no ordinary a...     PG
# 61  77  Until he was downsized, affable, amiable Larry...  PG-13
# 79  99  A woman finds herself attempting to foil one o...  PG-13
#
#                                                 genre  \
# 5                               Drama|Kids and Family
# 6                                              Comedy
# 7                                               Drama
# 18  Action and Adventure|Drama|Science Fiction and...
# 24          Action and Adventure|Mystery and Suspense
# 51                     Comedy|Kids and Family|Romance
# 53                                             Horror
# 56                               Action and Adventure
# 61                                       Comedy|Drama
# 79                                     Comedy|Romance
#
#                                director  \
# 5                           Jay Russell
# 6                           Jake Kasdan
# 7                          Ray Lawrence
# 18                     Carl Erik Rinsch
# 24                             John Woo
# 51                           Kevin Lima
# 53  Matt Bettinelli-Olpin|Tyler Gillett
# 56                     Steven Spielberg
# 61                            Tom Hanks
# 79                                  NaN
#
#                                                writer  theater_date  \
# 5                                     Gail Gilchriest   Mar 3, 2000
# 6                                          Mike White  Jan 11, 2002
# 7                    Raymond Carver|Beatrix Christian  Apr 27, 2006
# 18                         Chris Morgan|Hossein Amini  Dec 25, 2013
# 24  William Goldman|John Logan|David Marconi|Micha...  Dec 31, 2000
# 51                                                NaN  Nov 21, 2007
# 53                                     Lindsay Devlin  Jan 17, 2014
# 56                                    Lawrence Kasdan  Jun 12, 1981
# 61                             Tom Hanks|Nia Vardalos   Jul 1, 2011
# 79                                                NaN  Dec 20, 2002
#
#         dvd_date currency   box_office      runtime                  studio
# 5   Jul 11, 2000      NaN          NaN   95 minutes   Warner Bros. Pictures
# 6   Jun 18, 2002        $   41,032,915   82 minutes      Paramount Pictures
# 7    Oct 2, 2007        $      224,114  123 minutes  Sony Pictures Classics
# 18   Apr 1, 2014        $   20,518,224  127 minutes      Universal Pictures
# 24   Nov 7, 2000      NaN          NaN  123 minutes      Paramount Pictures
# 51  Mar 18, 2008        $  127,706,877  108 minutes    Buena Vista Pictures
# 53  Apr 29, 2014      NaN          NaN   89 minutes        20th Century Fox
# 56  Oct 21, 2003      NaN          NaN  115 minutes      Paramount Pictures
# 61  Nov 15, 2011        $   35,565,975   99 minutes      Universal Pictures
# 79  Apr 29, 2003        $   93,300,000  102 minutes   Warner Bros. Pictures

# %%
# Average runtime by studio
df_topstudio_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 5 to 1554
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            145 non-null    int64
#  1   synopsis      145 non-null    object
#  2   rating        145 non-null    object
#  3   genre         145 non-null    object
#  4   director      126 non-null    object
#  5   writer        115 non-null    object
#  6   theater_date  143 non-null    object
#  7   dvd_date      143 non-null    object
#  8   currency      105 non-null    object
#  9   box_office    105 non-null    object
#  10  runtime       143 non-null    object
#  11  studio        145 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 14.7+ KB

# %%
df_topstudio_model = df_topstudio_model.set_index('studio')
df_topstudio_model.head()
# Out:
#                         id                                           synopsis  \
# studio
# Warner Bros. Pictures    8  The year is 1942. As the Allies unite overseas...
# Paramount Pictures      10  Some cast and crew from NBC's highly acclaimed...
# Sony Pictures Classics  13  Stewart Kane, an Irishman living in the Austra...
# Universal Pictures      25  From ancient Japan's most enduring tale, the e...
# Paramount Pictures      34  Director John Woo brings Hong Kong-style marti...
#
#                        rating  \
# studio
# Warner Bros. Pictures      PG
# Paramount Pictures      PG-13
# Sony Pictures Classics      R
# Universal Pictures      PG-13
# Paramount Pictures      PG-13
#
#                                                                     genre  \
# studio
# Warner Bros. Pictures                               Drama|Kids and Family
# Paramount Pictures                                                 Comedy
# Sony Pictures Classics                                              Drama
# Universal Pictures      Action and Adventure|Drama|Science Fiction and...
# Paramount Pictures              Action and Adventure|Mystery and Suspense
#
#                                 director  \
# studio
# Warner Bros. Pictures        Jay Russell
# Paramount Pictures           Jake Kasdan
# Sony Pictures Classics      Ray Lawrence
# Universal Pictures      Carl Erik Rinsch
# Paramount Pictures              John Woo
#
#                                                                    writer  \
# studio
# Warner Bros. Pictures                                     Gail Gilchriest
# Paramount Pictures                                             Mike White
# Sony Pictures Classics                   Raymond Carver|Beatrix Christian
# Universal Pictures                             Chris Morgan|Hossein Amini
# Paramount Pictures      William Goldman|John Logan|David Marconi|Micha...
#
#                         theater_date      dvd_date currency  box_office  \
# studio
# Warner Bros. Pictures    Mar 3, 2000  Jul 11, 2000      NaN         NaN
# Paramount Pictures      Jan 11, 2002  Jun 18, 2002        $  41,032,915
# Sony Pictures Classics  Apr 27, 2006   Oct 2, 2007        $     224,114
# Universal Pictures      Dec 25, 2013   Apr 1, 2014        $  20,518,224
# Paramount Pictures      Dec 31, 2000   Nov 7, 2000      NaN         NaN
#
#                             runtime
# studio
# Warner Bros. Pictures    95 minutes
# Paramount Pictures       82 minutes
# Sony Pictures Classics  123 minutes
# Universal Pictures      127 minutes
# Paramount Pictures      123 minutes

# %%
df_topstudio_model['runtime'] = df_topstudio_model.runtime.str.split(" ", n = 1, expand = True)
df_topstudio_model = df_topstudio_model.rename(columns={'runtime': 'runtime_minutes'})
df_topstudio_model.head()
# Out:
#                         id                                           synopsis  \
# studio
# Warner Bros. Pictures    8  The year is 1942. As the Allies unite overseas...
# Paramount Pictures      10  Some cast and crew from NBC's highly acclaimed...
# Sony Pictures Classics  13  Stewart Kane, an Irishman living in the Austra...
# Universal Pictures      25  From ancient Japan's most enduring tale, the e...
# Paramount Pictures      34  Director John Woo brings Hong Kong-style marti...
#
#                        rating  \
# studio
# Warner Bros. Pictures      PG
# Paramount Pictures      PG-13
# Sony Pictures Classics      R
# Universal Pictures      PG-13
# Paramount Pictures      PG-13
#
#                                                                     genre  \
# studio
# Warner Bros. Pictures                               Drama|Kids and Family
# Paramount Pictures                                                 Comedy
# Sony Pictures Classics                                              Drama
# Universal Pictures      Action and Adventure|Drama|Science Fiction and...
# Paramount Pictures              Action and Adventure|Mystery and Suspense
#
#                                 director  \
# studio
# Warner Bros. Pictures        Jay Russell
# Paramount Pictures           Jake Kasdan
# Sony Pictures Classics      Ray Lawrence
# Universal Pictures      Carl Erik Rinsch
# Paramount Pictures              John Woo
#
#                                                                    writer  \
# studio
# Warner Bros. Pictures                                     Gail Gilchriest
# Paramount Pictures                                             Mike White
# Sony Pictures Classics                   Raymond Carver|Beatrix Christian
# Universal Pictures                             Chris Morgan|Hossein Amini
# Paramount Pictures      William Goldman|John Logan|David Marconi|Micha...
#
#                         theater_date      dvd_date currency  box_office  \
# studio
# Warner Bros. Pictures    Mar 3, 2000  Jul 11, 2000      NaN         NaN
# Paramount Pictures      Jan 11, 2002  Jun 18, 2002        $  41,032,915
# Sony Pictures Classics  Apr 27, 2006   Oct 2, 2007        $     224,114
# Universal Pictures      Dec 25, 2013   Apr 1, 2014        $  20,518,224
# Paramount Pictures      Dec 31, 2000   Nov 7, 2000      NaN         NaN
#
#                        runtime_minutes
# studio
# Warner Bros. Pictures               95
# Paramount Pictures                  82
# Sony Pictures Classics             123
# Universal Pictures                 127
# Paramount Pictures                 123

# %%
df_topstudio_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, Warner Bros. Pictures to Warner Bros. Pictures
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               145 non-null    int64
#  1   synopsis         145 non-null    object
#  2   rating           145 non-null    object
#  3   genre            145 non-null    object
#  4   director         126 non-null    object
#  5   writer           115 non-null    object
#  6   theater_date     143 non-null    object
#  7   dvd_date         143 non-null    object
#  8   currency         105 non-null    object
#  9   box_office       105 non-null    object
#  10  runtime_minutes  143 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 13.6+ KB

# %%
#Convert runtime_minutes col to int
df_topstudio_model_runtime = pd.to_numeric(df_topstudio_model.runtime_minutes, errors='coerce')
df_topstudio_model_runtime = df_topstudio_model_runtime.reset_index()
df_topstudio_model_runtime.head()
# Out:
#                    studio  runtime_minutes
# 0   Warner Bros. Pictures             95.0
# 1      Paramount Pictures             82.0
# 2  Sony Pictures Classics            123.0
# 3      Universal Pictures            127.0
# 4      Paramount Pictures            123.0

# %%
df_topstudio_model_runtime.describe()
# Out:
#        runtime_minutes
# count       143.000000
# mean        111.951049
# std          22.379672
# min          70.000000
# 25%          97.000000
# 50%         109.000000
# 75%         121.000000
# max         229.000000

# %%
df_topstudio_model_runtime = df_topstudio_model_runtime.groupby('studio')['runtime_minutes'].agg('mean')
df_topstudio_model_runtime = df_topstudio_model_runtime.reset_index()
df_topstudio_model_runtime.head()
# Out:
#                    studio  runtime_minutes
# 0        20th Century Fox       104.500000
# 1    Buena Vista Pictures       101.400000
# 2      Paramount Pictures       108.925926
# 3  Sony Pictures Classics       110.095238
# 4      Universal Pictures       115.800000

# %%
df_topstudio_model_runtime = df_topstudio_model_runtime.sort_values(by = 'runtime_minutes', ascending = False)
df_topstudio_model_runtime.head()
# Out:
#                    studio  runtime_minutes
# 5   Warner Bros. Pictures       119.965517
# 4      Universal Pictures       115.800000
# 3  Sony Pictures Classics       110.095238
# 2      Paramount Pictures       108.925926
# 0        20th Century Fox       104.500000

# %%
df_topstudio_model_runtime.plot.barh(x='studio',  y = 'runtime_minutes', color = 'navy', figsize=(6, 8), legend=None)

plt.title('Average Runtime by Studio')
plt.xlabel('Minutes')

plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Create new df splitting genres
df_topstudio_model_genres = df_topstudio_model
df_topstudio_model_genres.head()
# Out:
#                         id                                           synopsis  \
# studio
# Warner Bros. Pictures    8  The year is 1942. As the Allies unite overseas...
# Paramount Pictures      10  Some cast and crew from NBC's highly acclaimed...
# Sony Pictures Classics  13  Stewart Kane, an Irishman living in the Austra...
# Universal Pictures      25  From ancient Japan's most enduring tale, the e...
# Paramount Pictures      34  Director John Woo brings Hong Kong-style marti...
#
#                        rating  \
# studio
# Warner Bros. Pictures      PG
# Paramount Pictures      PG-13
# Sony Pictures Classics      R
# Universal Pictures      PG-13
# Paramount Pictures      PG-13
#
#                                                                     genre  \
# studio
# Warner Bros. Pictures                               Drama|Kids and Family
# Paramount Pictures                                                 Comedy
# Sony Pictures Classics                                              Drama
# Universal Pictures      Action and Adventure|Drama|Science Fiction and...
# Paramount Pictures              Action and Adventure|Mystery and Suspense
#
#                                 director  \
# studio
# Warner Bros. Pictures        Jay Russell
# Paramount Pictures           Jake Kasdan
# Sony Pictures Classics      Ray Lawrence
# Universal Pictures      Carl Erik Rinsch
# Paramount Pictures              John Woo
#
#                                                                    writer  \
# studio
# Warner Bros. Pictures                                     Gail Gilchriest
# Paramount Pictures                                             Mike White
# Sony Pictures Classics                   Raymond Carver|Beatrix Christian
# Universal Pictures                             Chris Morgan|Hossein Amini
# Paramount Pictures      William Goldman|John Logan|David Marconi|Micha...
#
#                         theater_date      dvd_date currency  box_office  \
# studio
# Warner Bros. Pictures    Mar 3, 2000  Jul 11, 2000      NaN         NaN
# Paramount Pictures      Jan 11, 2002  Jun 18, 2002        $  41,032,915
# Sony Pictures Classics  Apr 27, 2006   Oct 2, 2007        $     224,114
# Universal Pictures      Dec 25, 2013   Apr 1, 2014        $  20,518,224
# Paramount Pictures      Dec 31, 2000   Nov 7, 2000      NaN         NaN
#
#                        runtime_minutes
# studio
# Warner Bros. Pictures               95
# Paramount Pictures                  82
# Sony Pictures Classics             123
# Universal Pictures                 127
# Paramount Pictures                 123

# %%
df_topstudio_model_genres = df_topstudio_model_genres['genre'].str.split("|", n=10, expand = True).rename(columns = lambda x: f"genre_{x+1}")
df_topstudio_model_genres.head(10)
# Out:
#                                      genre_1               genre_2  \
# studio
# Warner Bros. Pictures                  Drama       Kids and Family
# Paramount Pictures                    Comedy                  None
# Sony Pictures Classics                 Drama                  None
# Universal Pictures      Action and Adventure                 Drama
# Paramount Pictures      Action and Adventure  Mystery and Suspense
# Buena Vista Pictures                  Comedy       Kids and Family
# 20th Century Fox                      Horror                  None
# Paramount Pictures      Action and Adventure                  None
# Universal Pictures                    Comedy                 Drama
# Warner Bros. Pictures                 Comedy               Romance
#
#                                             genre_3 genre_4 genre_5
# studio
# Warner Bros. Pictures                          None    None    None
# Paramount Pictures                             None    None    None
# Sony Pictures Classics                         None    None    None
# Universal Pictures      Science Fiction and Fantasy    None    None
# Paramount Pictures                             None    None    None
# Buena Vista Pictures                        Romance    None    None
# 20th Century Fox                               None    None    None
# Paramount Pictures                             None    None    None
# Universal Pictures                             None    None    None
# Warner Bros. Pictures                          None    None    None

# %%
# Genre value counts by studio

# %%
genres_pct = df_topstudio_model_genres.stack().value_counts(normalize=True, dropna=True).mul(100).round(1)

# %%
genres_pct
# Out:
# Drama                          25.7
# Comedy                         20.7
# Action and Adventure           13.7
# Mystery and Suspense            8.7
# Science Fiction and Fantasy     7.7
# Kids and Family                 5.3
# Romance                         5.0
# Art House and International     3.3
# Horror                          2.7
# Animation                       2.7
# Western                         1.3
# Musical and Performing Arts     1.0
# Television                      0.7
# Documentary                     0.7
# Classics                        0.3
# Sports and Fitness              0.3
# Special Interest                0.3
# dtype: float64

# %%
genres_pct.plot(kind = 'barh', color = 'navy', figsize=(6,8))
plt.title('Genres Produced by Top Studios')
plt.gca().invert_yaxis()
plt.xlabel('Percent of films produced')
plt.show()
