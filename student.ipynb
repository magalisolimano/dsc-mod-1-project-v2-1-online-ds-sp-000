# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Magali Solimano
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name: Jeff Herman
# * Blog post URL:

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
## Load the data (11 files)
df1 = pd.read_csv('zippedData/bom.movie_gross.csv.gz', compression='gzip')
df2 = pd.read_csv('zippedData/imdb.name.basics.csv.gz', compression='gzip')
df3 = pd.read_csv('zippedData/imdb.title.akas.csv.gz', compression='gzip')
df4 = pd.read_csv('zippedData/imdb.title.basics.csv.gz', compression='gzip') 
df5 = pd.read_csv('zippedData/imdb.title.crew.csv.gz', compression='gzip')
df6 = pd.read_csv('zippedData/imdb.title.principals.csv.gz', compression='gzip')
df7 = pd.read_csv('zippedData/imdb.title.ratings.csv.gz', compression='gzip')
df8 = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t', compression='gzip')
df9 = pd.read_csv('zippedData/rt.reviews.tsv.gz', compression='gzip', delimiter='\t', encoding='iso-8859-1')
df10 = pd.read_csv('zippedData/tmdb.movies.csv.gz', compression='gzip')
df11 = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', compression='gzip')

# %%
# Explore the dataframes and data types
print(df1.info())
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# None
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
print(df2.info())
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB
# None
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
print(df3.info())
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   title_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB
# None
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
print(df4.info())
df4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
print(df5.info())
df5.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB
# None
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
print(df6.info())
df6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
print(df7.info())
df7.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
print(df8.info())
df8.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB
# None
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
print(df9.info())
df9.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB
# None
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
# Drop 'id' col?
df9.id.unique()
# Out:
# array([   3,    5,    6, ..., 1998, 1999, 2000])

# %%
print(df10.info())
df10.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
# None
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df10 = df10.drop(columns=['Unnamed: 0'])
df10.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
print(df11.info())
df11.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
## QUESTION 1: What movies are the top revenue generators?

# %%
#df1 and #df11 have revenue cols -- compare these results. Can the dfs be joined?

# %%
# Convert foreign_gross dtype to float and rename col. Create new worldwide col
df1['foreign_gross'] = pd.to_numeric(df1['foreign_gross'], errors='coerce')
display(df1.info())
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2032 non-null   float64
#  4   year            3387 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 132.4+ KB
# None
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691300000.0  2010
# 2    664300000.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
# Convert budget and revenue cols to float dtype; release_date to datetime. Remove '$' and ','.
df11['production_budget'] = df11['production_budget'].map(lambda x: float(x.replace("$", "").replace(',','')))
df11['domestic_gross'] = df11['domestic_gross'].map(lambda x: float(x.replace("$", "").replace(',','')))
df11['worldwide_gross'] = df11['worldwide_gross'].map(lambda x: float(x.replace("$", "").replace(',','')))
df11['release_date'] = pd.to_datetime(df11['release_date'])
df11['year'] = pd.DatetimeIndex(df11['release_date']).year

# Confirm that dtype conversions worked and that null values did not increase
display(df11.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
#  6   year               5782 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 316.3+ KB
# None

# %%
df11 = df11.rename(columns={"movie": "title"})
df11.head()
# Out:
#    id release_date                                        title  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  year
# 0        425000000.0     760507625.0     2.776345e+09  2009
# 1        410600000.0     241063875.0     1.045664e+09  2011
# 2        350000000.0      42762350.0     1.497624e+08  2019
# 3        330600000.0     459005868.0     1.403014e+09  2015
# 4        317000000.0     620181382.0     1.316722e+09  2017

# %%
# Compare top gross: df1 vs df11

# %%
display(df1.sort_values(by=['domestic_gross'], ascending=False).head(20))
df11.sort_values(by=['domestic_gross'], ascending=False).head(20)
# Out:
#                                 title studio  domestic_gross  foreign_gross  \
# 1872     Star Wars: The Force Awakens     BV     936700000.0            NaN
# 3080                    Black Panther     BV     700100000.0    646900000.0
# 3079           Avengers: Infinity War     BV     678800000.0            NaN
# 1873                   Jurassic World   Uni.     652300000.0            NaN
# 727             Marvel's The Avengers     BV     623400000.0    895500000.0
# 2758         Star Wars: The Last Jedi     BV     620200000.0    712400000.0
# 3082                    Incredibles 2     BV     608600000.0    634200000.0
# 2323     Rogue One: A Star Wars Story     BV     532200000.0    523900000.0
# 2759      Beauty and the Beast (2017)     BV     504000000.0    759500000.0
# 2324                     Finding Dory     BV     486300000.0    542300000.0
# 1875          Avengers: Age of Ultron     BV     459000000.0    946400000.0
# 729             The Dark Knight Rises     WB     448100000.0    636800000.0
# 1131  The Hunger Games: Catching Fire    LGF     424700000.0    440300000.0
# 3081   Jurassic World: Fallen Kingdom   Uni.     417700000.0    891800000.0
# 0                         Toy Story 3     BV     415000000.0    652000000.0
# 2767                     Wonder Woman     WB     412600000.0    409300000.0
# 1128                       Iron Man 3     BV     409000000.0    805800000.0
# 2322       Captain America: Civil War     BV     408100000.0    745200000.0
# 735                  The Hunger Games    LGF     408000000.0    286400000.0
# 2762   Jumanji: Welcome to the Jungle   Sony     404500000.0    557600000.0
#
#       year
# 1872  2015
# 3080  2018
# 3079  2018
# 1873  2015
# 727   2012
# 2758  2017
# 3082  2018
# 2323  2016
# 2759  2017
# 2324  2016
# 1875  2015
# 729   2012
# 1131  2013
# 3081  2018
# 0     2010
# 2767  2017
# 1128  2013
# 2322  2016
# 735   2012
# 2762  2017
#       id release_date                                 title  \
# 5      6   2015-12-18  Star Wars Ep. VII: The Force Awakens
# 0      1   2009-12-18                                Avatar
# 41    42   2018-02-16                         Black Panther
# 6      7   2018-04-27                Avengers: Infinity War
# 42    43   1997-12-19                               Titanic
# 33    34   2015-06-12                        Jurassic World
# 26    27   2012-05-04                          The Avengers
# 4      5   2017-12-15     Star Wars Ep. VIII: The Last Jedi
# 43    44   2018-06-15                         Incredibles 2
# 74    75   2008-07-18                       The Dark Knight
# 44    45   2016-12-16          Rogue One: A Star Wars Story
# 134   35   2017-03-17                  Beauty and the Beast
# 45    46   2016-06-17                          Finding Dory
# 303    4   1999-05-19   Star Wars Ep. I: The Phantom Menace
# 3464  65   1977-05-25          Star Wars Ep. IV: A New Hope
# 3      4   2015-05-01               Avengers: Age of Ultron
# 10    11   2012-07-20                 The Dark Knight Rises
# 692   93   2004-05-19                               Shrek 2
# 3525  26   1982-06-11             ET: The Extra-Terrestrial
# 95    96   2019-03-08                        Captain Marvel
#
#       production_budget  domestic_gross  worldwide_gross  year
# 5           306000000.0     936662225.0     2.053311e+09  2015
# 0           425000000.0     760507625.0     2.776345e+09  2009
# 41          200000000.0     700059566.0     1.348258e+09  2018
# 6           300000000.0     678815482.0     2.048134e+09  2018
# 42          200000000.0     659363944.0     2.208208e+09  1997
# 33          215000000.0     652270625.0     1.648855e+09  2015
# 26          225000000.0     623279547.0     1.517936e+09  2012
# 4           317000000.0     620181382.0     1.316722e+09  2017
# 43          200000000.0     608581744.0     1.242521e+09  2018
# 74          185000000.0     533720947.0     1.001996e+09  2008
# 44          200000000.0     532177324.0     1.049103e+09  2016
# 134         160000000.0     504014165.0     1.259200e+09  2017
# 45          200000000.0     486295561.0     1.021215e+09  2016
# 303         115000000.0     474544677.0     1.027045e+09  1999
# 3464         11000000.0     460998007.0     7.865980e+08  1977
# 3           330600000.0     459005868.0     1.403014e+09  2015
# 10          275000000.0     448139099.0     1.084439e+09  2012
# 692          70000000.0     441226247.0     9.370081e+08  2004
# 3525         10500000.0     435110554.0     7.929653e+08  1982
# 95          175000000.0     426525952.0     1.123062e+09  2019

# %%
# There is overlap between df1 & df11. But, df11 has more movie entries (incl. several top revenue generators) that are not in df1.
# df1 might not have a particular studio's movies.

# %%
# Set index to title.
# Join df11 and df1--left join to bring in df1's studio info.

# %%
df1.set_index('title', inplace = True)
df1.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                              foreign_gross  year
# title
# Toy Story 3                                    652000000.0  2010
# Alice in Wonderland (2010)                     691300000.0  2010
# Harry Potter and the Deathly Hallows Part 1    664300000.0  2010
# Inception                                      535700000.0  2010
# Shrek Forever After                            513900000.0  2010

# %%
df11.set_index('title', inplace = True)
df11.head()
# Out:
#                                              id release_date  \
# title
# Avatar                                        1   2009-12-18
# Pirates of the Caribbean: On Stranger Tides   2   2011-05-20
# Dark Phoenix                                  3   2019-06-07
# Avengers: Age of Ultron                       4   2015-05-01
# Star Wars Ep. VIII: The Last Jedi             5   2017-12-15
#
#                                              production_budget  \
# title
# Avatar                                             425000000.0
# Pirates of the Caribbean: On Stranger Tides        410600000.0
# Dark Phoenix                                       350000000.0
# Avengers: Age of Ultron                            330600000.0
# Star Wars Ep. VIII: The Last Jedi                  317000000.0
#
#                                              domestic_gross  worldwide_gross  \
# title
# Avatar                                          760507625.0     2.776345e+09
# Pirates of the Caribbean: On Stranger Tides     241063875.0     1.045664e+09
# Dark Phoenix                                     42762350.0     1.497624e+08
# Avengers: Age of Ultron                         459005868.0     1.403014e+09
# Star Wars Ep. VIII: The Last Jedi               620181382.0     1.316722e+09
#
#                                              year
# title
# Avatar                                       2009
# Pirates of the Caribbean: On Stranger Tides  2011
# Dark Phoenix                                 2019
# Avengers: Age of Ultron                      2015
# Star Wars Ep. VIII: The Last Jedi            2017

# %%
df_revenue = df11.join(df1, how='left', rsuffix='_right')
display(df_revenue.info())
df_revenue.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5782 entries, #Horror to é·æ±ä¸è (CJ7)
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5782 non-null   int64
#  1   release_date          5782 non-null   datetime64[ns]
#  2   production_budget     5782 non-null   float64
#  3   domestic_gross        5782 non-null   float64
#  4   worldwide_gross       5782 non-null   float64
#  5   year                  5782 non-null   int64
#  6   studio                1246 non-null   object
#  7   domestic_gross_right  1245 non-null   float64
#  8   foreign_gross         1082 non-null   float64
#  9   year_right            1247 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 496.9+ KB
# None
#                                            id release_date  production_budget  \
# title
# #Horror                                    16   2015-11-20          1500000.0
# (500) Days of Summer                       55   2009-07-17          7500000.0
# 10 Cloverfield Lane                        54   2016-03-11          5000000.0
# 10 Days in a Madhouse                      48   2015-11-11         12000000.0
# 10 Things I Hate About You                 63   1999-03-31         13000000.0
# 10,000 B.C.                                51   2008-03-07        105000000.0
# 102 Dalmatians                              6   2000-11-22         85000000.0
# 10th & Wolf                                32   2006-08-18          8000000.0
# 11:14                                      90   2005-08-12          6000000.0
# 12 Angry Men                               36   1957-04-13           340000.0
# 12 Monkeys                                 18   1995-12-27         29000000.0
# 12 Rounds                                  37   2009-03-27         20000000.0
# 12 Strong                                  64   2018-01-19         35000000.0
# 12 Years a Slave                           18   2013-10-18         20000000.0
# 127 Hours                                   6   2010-11-05         18000000.0
# 13 Going On 30                             96   2004-04-23         37000000.0
# 13 Hours: The Secret Soldiers of Benghazi  30   2016-01-15         50000000.0
# 13 Sins                                    51   2014-04-18          4000000.0
# 1408                                        2   2007-06-22         22500000.0
# 15 Minutes                                 60   2001-03-09         42000000.0
#
#                                            domestic_gross  worldwide_gross  \
# title
# #Horror                                               0.0              0.0
# (500) Days of Summer                           32425665.0       34439060.0
# 10 Cloverfield Lane                            72082999.0      108286422.0
# 10 Days in a Madhouse                             14616.0          14616.0
# 10 Things I Hate About You                     38177966.0       60413950.0
# 10,000 B.C.                                    94784201.0      269065678.0
# 102 Dalmatians                                 66941559.0       66941559.0
# 10th & Wolf                                       54702.0         143782.0
# 11:14                                                 0.0              0.0
# 12 Angry Men                                          0.0              0.0
# 12 Monkeys                                     57141459.0      168841459.0
# 12 Rounds                                      12234694.0       17306648.0
# 12 Strong                                      45819713.0       71118378.0
# 12 Years a Slave                               56671993.0      181025343.0
# 127 Hours                                      18335230.0       60217171.0
# 13 Going On 30                                 57139723.0       97658712.0
# 13 Hours: The Secret Soldiers of Benghazi      52853219.0       69411370.0
# 13 Sins                                            9134.0          47552.0
# 1408                                           71985628.0      131263370.0
# 15 Minutes                                     24375436.0       56331864.0
#
#                                            year studio  domestic_gross_right  \
# title
# #Horror                                    2015    NaN                   NaN
# (500) Days of Summer                       2009    NaN                   NaN
# 10 Cloverfield Lane                        2016   Par.            72100000.0
# 10 Days in a Madhouse                      2015    NaN                   NaN
# 10 Things I Hate About You                 1999    NaN                   NaN
# 10,000 B.C.                                2008    NaN                   NaN
# 102 Dalmatians                             2000    NaN                   NaN
# 10th & Wolf                                2006    NaN                   NaN
# 11:14                                      2005    NaN                   NaN
# 12 Angry Men                               1957    NaN                   NaN
# 12 Monkeys                                 1995    NaN                   NaN
# 12 Rounds                                  2009    NaN                   NaN
# 12 Strong                                  2018     WB            45800000.0
# 12 Years a Slave                           2013   FoxS            56700000.0
# 127 Hours                                  2010   FoxS            18300000.0
# 13 Going On 30                             2004    NaN                   NaN
# 13 Hours: The Secret Soldiers of Benghazi  2016   Par.            52900000.0
# 13 Sins                                    2014   RTWC               13800.0
# 1408                                       2007    NaN                   NaN
# 15 Minutes                                 2001    NaN                   NaN
#
#                                            foreign_gross  year_right
# title
# #Horror                                              NaN         NaN
# (500) Days of Summer                                 NaN         NaN
# 10 Cloverfield Lane                           38100000.0      2016.0
# 10 Days in a Madhouse                                NaN         NaN
# 10 Things I Hate About You                           NaN         NaN
# 10,000 B.C.                                          NaN         NaN
# 102 Dalmatians                                       NaN         NaN
# 10th & Wolf                                          NaN         NaN
# 11:14                                                NaN         NaN
# 12 Angry Men                                         NaN         NaN
# 12 Monkeys                                           NaN         NaN
# 12 Rounds                                            NaN         NaN
# 12 Strong                                     21600000.0      2018.0
# 12 Years a Slave                             131100000.0      2013.0
# 127 Hours                                     42400000.0      2010.0
# 13 Going On 30                                       NaN         NaN
# 13 Hours: The Secret Soldiers of Benghazi     16600000.0      2016.0
# 13 Sins                                              NaN      2014.0
# 1408                                                 NaN         NaN
# 15 Minutes                                           NaN         NaN

# %%
# Drop df1 revenue data since they seem to round, while df11's revenue data is more precise.
# Drop foreign_gross, year_right.

# %%
df_revenue = df_revenue.drop(columns=['domestic_gross_right', 'foreign_gross', 'year_right'])

# %%
# Calculate foreign gross revenue as difference between worldwide and domestic revenue
df_revenue['foreign_gross'] = df_revenue['worldwide_gross'] - df_revenue['domestic_gross']
df_revenue.head()
# Out:
#                             id release_date  production_budget  \
# title
# #Horror                     16   2015-11-20          1500000.0
# (500) Days of Summer        55   2009-07-17          7500000.0
# 10 Cloverfield Lane         54   2016-03-11          5000000.0
# 10 Days in a Madhouse       48   2015-11-11         12000000.0
# 10 Things I Hate About You  63   1999-03-31         13000000.0
#
#                             domestic_gross  worldwide_gross  year studio  \
# title
# #Horror                                0.0              0.0  2015    NaN
# (500) Days of Summer            32425665.0       34439060.0  2009    NaN
# 10 Cloverfield Lane             72082999.0      108286422.0  2016   Par.
# 10 Days in a Madhouse              14616.0          14616.0  2015    NaN
# 10 Things I Hate About You      38177966.0       60413950.0  1999    NaN
#
#                             foreign_gross
# title
# #Horror                               0.0
# (500) Days of Summer            2013395.0
# 10 Cloverfield Lane            36203423.0
# 10 Days in a Madhouse                 0.0
# 10 Things I Hate About You     22235984.0

# %%
# Convert "0" values to NaN
df_revenue['production_budget'] = df_revenue['production_budget'].replace(0.0, np.nan)
df_revenue['domestic_gross'] = df_revenue['domestic_gross'].replace(0.0, np.nan)
df_revenue['worldwide_gross'] = df_revenue['worldwide_gross'].replace(0.0, np.nan)
df_revenue['foreign_gross'] = df_revenue['foreign_gross'].replace(0.0, np.nan)
df_revenue.head(10)
# Out:
#                             id release_date  production_budget  \
# title
# #Horror                     16   2015-11-20          1500000.0
# (500) Days of Summer        55   2009-07-17          7500000.0
# 10 Cloverfield Lane         54   2016-03-11          5000000.0
# 10 Days in a Madhouse       48   2015-11-11         12000000.0
# 10 Things I Hate About You  63   1999-03-31         13000000.0
# 10,000 B.C.                 51   2008-03-07        105000000.0
# 102 Dalmatians               6   2000-11-22         85000000.0
# 10th & Wolf                 32   2006-08-18          8000000.0
# 11:14                       90   2005-08-12          6000000.0
# 12 Angry Men                36   1957-04-13           340000.0
#
#                             domestic_gross  worldwide_gross  year studio  \
# title
# #Horror                                NaN              NaN  2015    NaN
# (500) Days of Summer            32425665.0       34439060.0  2009    NaN
# 10 Cloverfield Lane             72082999.0      108286422.0  2016   Par.
# 10 Days in a Madhouse              14616.0          14616.0  2015    NaN
# 10 Things I Hate About You      38177966.0       60413950.0  1999    NaN
# 10,000 B.C.                     94784201.0      269065678.0  2008    NaN
# 102 Dalmatians                  66941559.0       66941559.0  2000    NaN
# 10th & Wolf                        54702.0         143782.0  2006    NaN
# 11:14                                  NaN              NaN  2005    NaN
# 12 Angry Men                           NaN              NaN  1957    NaN
#
#                             foreign_gross
# title
# #Horror                               NaN
# (500) Days of Summer            2013395.0
# 10 Cloverfield Lane            36203423.0
# 10 Days in a Madhouse                 NaN
# 10 Things I Hate About You     22235984.0
# 10,000 B.C.                   174281477.0
# 102 Dalmatians                        NaN
# 10th & Wolf                       89080.0
# 11:14                                 NaN
# 12 Angry Men                          NaN

# %%
df_revenue['net_revenue'] = df_revenue['worldwide_gross'] - df_revenue['production_budget']
df_revenue['ROI'] = (df_revenue['net_revenue'] / df_revenue['production_budget']).round(2)
df_revenue.head(25)
# Out:
#                                            id release_date  production_budget  \
# title
# #Horror                                    16   2015-11-20          1500000.0
# (500) Days of Summer                       55   2009-07-17          7500000.0
# 10 Cloverfield Lane                        54   2016-03-11          5000000.0
# 10 Days in a Madhouse                      48   2015-11-11         12000000.0
# 10 Things I Hate About You                 63   1999-03-31         13000000.0
# 10,000 B.C.                                51   2008-03-07        105000000.0
# 102 Dalmatians                              6   2000-11-22         85000000.0
# 10th & Wolf                                32   2006-08-18          8000000.0
# 11:14                                      90   2005-08-12          6000000.0
# 12 Angry Men                               36   1957-04-13           340000.0
# 12 Monkeys                                 18   1995-12-27         29000000.0
# 12 Rounds                                  37   2009-03-27         20000000.0
# 12 Strong                                  64   2018-01-19         35000000.0
# 12 Years a Slave                           18   2013-10-18         20000000.0
# 127 Hours                                   6   2010-11-05         18000000.0
# 13 Going On 30                             96   2004-04-23         37000000.0
# 13 Hours: The Secret Soldiers of Benghazi  30   2016-01-15         50000000.0
# 13 Sins                                    51   2014-04-18          4000000.0
# 1408                                        2   2007-06-22         22500000.0
# 15 Minutes                                 60   2001-03-09         42000000.0
# 16 Blocks                                  93   2006-03-03         45000000.0
# 16 to Life                                 90   2010-09-03          1000000.0
# 1612                                       49   2009-04-07         12000000.0
# 17 Again                                   20   2009-04-17         40000000.0
# 1776                                       59   1972-11-09          4000000.0
#
#                                            domestic_gross  worldwide_gross  \
# title
# #Horror                                               NaN              NaN
# (500) Days of Summer                           32425665.0       34439060.0
# 10 Cloverfield Lane                            72082999.0      108286422.0
# 10 Days in a Madhouse                             14616.0          14616.0
# 10 Things I Hate About You                     38177966.0       60413950.0
# 10,000 B.C.                                    94784201.0      269065678.0
# 102 Dalmatians                                 66941559.0       66941559.0
# 10th & Wolf                                       54702.0         143782.0
# 11:14                                                 NaN              NaN
# 12 Angry Men                                          NaN              NaN
# 12 Monkeys                                     57141459.0      168841459.0
# 12 Rounds                                      12234694.0       17306648.0
# 12 Strong                                      45819713.0       71118378.0
# 12 Years a Slave                               56671993.0      181025343.0
# 127 Hours                                      18335230.0       60217171.0
# 13 Going On 30                                 57139723.0       97658712.0
# 13 Hours: The Secret Soldiers of Benghazi      52853219.0       69411370.0
# 13 Sins                                            9134.0          47552.0
# 1408                                           71985628.0      131263370.0
# 15 Minutes                                     24375436.0       56331864.0
# 16 Blocks                                      36895141.0       65595141.0
# 16 to Life                                        11574.0          11574.0
# 1612                                                  NaN        5400624.0
# 17 Again                                       64167069.0      139474906.0
# 1776                                                  NaN              NaN
#
#                                            year studio  foreign_gross  \
# title
# #Horror                                    2015    NaN            NaN
# (500) Days of Summer                       2009    NaN      2013395.0
# 10 Cloverfield Lane                        2016   Par.     36203423.0
# 10 Days in a Madhouse                      2015    NaN            NaN
# 10 Things I Hate About You                 1999    NaN     22235984.0
# 10,000 B.C.                                2008    NaN    174281477.0
# 102 Dalmatians                             2000    NaN            NaN
# 10th & Wolf                                2006    NaN        89080.0
# 11:14                                      2005    NaN            NaN
# 12 Angry Men                               1957    NaN            NaN
# 12 Monkeys                                 1995    NaN    111700000.0
# 12 Rounds                                  2009    NaN      5071954.0
# 12 Strong                                  2018     WB     25298665.0
# 12 Years a Slave                           2013   FoxS    124353350.0
# 127 Hours                                  2010   FoxS     41881941.0
# 13 Going On 30                             2004    NaN     40518989.0
# 13 Hours: The Secret Soldiers of Benghazi  2016   Par.     16558151.0
# 13 Sins                                    2014   RTWC        38418.0
# 1408                                       2007    NaN     59277742.0
# 15 Minutes                                 2001    NaN     31956428.0
# 16 Blocks                                  2006    NaN     28700000.0
# 16 to Life                                 2010    NaN            NaN
# 1612                                       2009    NaN      5400624.0
# 17 Again                                   2009    NaN     75307837.0
# 1776                                       1972    NaN            NaN
#
#                                            net_revenue    ROI
# title
# #Horror                                            NaN    NaN
# (500) Days of Summer                        26939060.0   3.59
# 10 Cloverfield Lane                        103286422.0  20.66
# 10 Days in a Madhouse                      -11985384.0  -1.00
# 10 Things I Hate About You                  47413950.0   3.65
# 10,000 B.C.                                164065678.0   1.56
# 102 Dalmatians                             -18058441.0  -0.21
# 10th & Wolf                                 -7856218.0  -0.98
# 11:14                                              NaN    NaN
# 12 Angry Men                                       NaN    NaN
# 12 Monkeys                                 139841459.0   4.82
# 12 Rounds                                   -2693352.0  -0.13
# 12 Strong                                   36118378.0   1.03
# 12 Years a Slave                           161025343.0   8.05
# 127 Hours                                   42217171.0   2.35
# 13 Going On 30                              60658712.0   1.64
# 13 Hours: The Secret Soldiers of Benghazi   19411370.0   0.39
# 13 Sins                                     -3952448.0  -0.99
# 1408                                       108763370.0   4.83
# 15 Minutes                                  14331864.0   0.34
# 16 Blocks                                   20595141.0   0.46
# 16 to Life                                   -988426.0  -0.99
# 1612                                        -6599376.0  -0.55
# 17 Again                                    99474906.0   2.49
# 1776                                               NaN    NaN

# %%
df_revenue.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5782.000000       5.782000e+03    5.234000e+03     5.415000e+03
# mean     50.372363       3.158776e+07    4.625747e+07     9.768800e+07
# std      28.821076       4.181208e+07    7.029651e+07     1.788591e+08
# min       1.000000       1.100000e+03    3.880000e+02     2.600000e+01
# 25%      25.000000       5.000000e+06    4.289718e+06     7.004834e+06
# 50%      50.000000       1.700000e+07    2.198422e+07     3.333987e+07
# 75%      75.000000       4.000000e+07    5.756598e+07     1.044590e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#               year  foreign_gross   net_revenue          ROI
# count  5782.000000   4.163000e+03  5.415000e+03  5415.000000
# mean   2003.967139   6.890918e+07  6.437999e+07     4.125453
# std      12.724386   1.282326e+08  1.498581e+08    30.487388
# min    1915.000000   2.600000e+01 -2.002376e+08    -1.000000
# 25%    2000.000000   3.347353e+06 -1.862082e+06    -0.300000
# 50%    2007.000000   2.183036e+07  1.190000e+07     0.880000
# 75%    2012.000000   7.568069e+07  6.737924e+07     2.970000
# max    2020.000000   2.015838e+09  2.351345e+09  1799.000000

# %%
# reset index
df_revenue.reset_index(inplace = True)

# %%
# Check for duplicates. Explore if need to remove or can keep.
df_revenue['title'].value_counts()
# Out:
# King Kong                  3
# Halloween                  3
# Home                       3
# Trance                     2
# Crossroads                 2
#                           ..
# Pacific Rim: Uprising      1
# Army of Darkness           1
# Dreamcatcher               1
# The Runaways               1
# Beverly Hills Chihuahua    1
# Name: title, Length: 5698, dtype: int64

# %%
df_revenue[df_revenue['title'].duplicated() == True]
# Out:
#                              title  id release_date  production_budget  \
# 33    20,000 Leagues Under the Sea  15   1916-12-24           200000.0
# 141      A Nightmare on Elm Street  17   1984-11-09          1800000.0
# 232                        Aladdin  33   1992-11-11         28000000.0
# 246            Alice in Wonderland  60   1951-07-28          3000000.0
# 406    Around the World in 80 Days  21   1956-10-17          6000000.0
# ...                            ...  ..          ...                ...
# 5351                        Trance  31   2012-12-31           950000.0
# 5408                      Twilight  20   1998-03-06         20000000.0
# 5463                 Unforgettable   4   2017-04-21         12000000.0
# 5472                       Unknown  84   2006-11-03          3700000.0
# 5512                         Venom  14   2005-09-16         25000000.0
#
#       domestic_gross  worldwide_gross  year studio  foreign_gross  \
# 33         8000000.0        8000000.0  1916    NaN            NaN
# 141       25504513.0       25504513.0  1984    NaN            NaN
# 232      217350219.0      504050219.0  1992    NaN    286700000.0
# 246              NaN              NaN  1951    NaN            NaN
# 406       42000000.0       42000000.0  1956    NaN            NaN
# ...              ...              ...   ...    ...            ...
# 5351             NaN              NaN  2012   FoxS            NaN
# 5408      15055091.0       15055091.0  1998    NaN            NaN
# 5463      11368012.0       16221211.0  2017    NaN      4853199.0
# 5472         26403.0        3355048.0  2006     WB      3328645.0
# 5512        881745.0         881745.0  2005    NaN            NaN
#
#       net_revenue    ROI
# 33      7800000.0  39.00
# 141    23704513.0  13.17
# 232   476050219.0  17.00
# 246           NaN    NaN
# 406    36000000.0   6.00
# ...           ...    ...
# 5351          NaN    NaN
# 5408   -4944909.0  -0.25
# 5463    4221211.0   0.35
# 5472    -344952.0  -0.09
# 5512  -24118255.0  -0.96
#
# [84 rows x 11 columns]

# %%
# view selection of rows with duplicate titles
df_revenue.sort_values('title').iloc[231:250, :]
# Out:
#                                                  title   id release_date  \
# 231                                            Aladdin   81   2019-05-24
# 232                                            Aladdin   33   1992-11-11
# 233                                          Alatriste   81   2007-12-31
# 234                                       Albert Nobbs   67   2011-12-21
# 235                                   Albino Alligator   65   1997-01-17
# 236                                        Alex & Emma   70   2003-06-20
# 237                                         Alex Cross  100   2012-10-19
# 238                 Alex Rider: Operation Stormbreaker   34   2006-10-13
# 239                                          Alexander   51   2004-11-24
# 240  Alexander and the Terrible, Horrible, No Good,...   44   2014-10-10
# 241                           Alexander's Ragtime Band   18   1938-05-24
# 242                                              Alfie   12   2004-11-05
# 243                                                Ali   45   2001-12-25
# 244                    Alice Through the Looking Glass   26   2016-05-27
# 246                                Alice in Wonderland   60   1951-07-28
# 245                                Alice in Wonderland   51   2010-03-05
# 247                                              Alien   21   1979-05-25
# 248                                            Alien 3   17   1992-05-22
# 249                                     Alien Uprising   44   2013-06-21
#
#      production_budget  domestic_gross  worldwide_gross  year studio  \
# 231        182000000.0     246734314.0     6.192343e+08  2019    NaN
# 232         28000000.0     217350219.0     5.040502e+08  1992    NaN
# 233         28000000.0             NaN     2.286048e+07  2007    NaN
# 234          7500000.0       3014696.0     8.539003e+06  2011  RAtt.
# 235          5000000.0        353480.0     3.534800e+05  1997    NaN
# 236         30000000.0      14208384.0     1.535858e+07  2003    NaN
# 237         35000000.0      25888412.0     3.542676e+07  2012   LG/S
# 238         40000000.0        659210.0     2.072245e+07  2006    NaN
# 239        155000000.0      34297191.0     1.672972e+08  2004    NaN
# 240         28000000.0      66954149.0     1.013793e+08  2014     BV
# 241          2000000.0       4000000.0     4.000000e+06  1938    NaN
# 242         40000000.0      13395939.0     3.519594e+07  2004    NaN
# 243        109000000.0      58183966.0     8.768397e+07  2001    NaN
# 244        170000000.0      77042381.0     2.769281e+08  2016     BV
# 246          3000000.0             NaN              NaN  1951    NaN
# 245        200000000.0     334191110.0     1.025491e+09  2010    NaN
# 247         10700000.0      80930630.0     2.036289e+08  1979    NaN
# 248         55000000.0      54927174.0     1.585000e+08  1992    NaN
# 249          2500000.0             NaN              NaN  2013    NaN
#
#      foreign_gross  net_revenue    ROI
# 231    372500000.0  437234314.0   2.40
# 232    286700000.0  476050219.0  17.00
# 233     22860477.0   -5139523.0  -0.18
# 234      5524307.0    1039003.0   0.14
# 235            NaN   -4646520.0  -0.93
# 236      1150199.0  -14641417.0  -0.49
# 237      9538347.0     426759.0   0.01
# 238     20063240.0  -19277550.0  -0.48
# 239    133000000.0   12297191.0   0.08
# 240     34425138.0   73379287.0   2.62
# 241            NaN    2000000.0   1.00
# 242     21800000.0   -4804061.0  -0.12
# 243     29500000.0  -21316034.0  -0.20
# 244    199885731.0  106928112.0   0.63
# 246            NaN          NaN    NaN
# 245    691300000.0  825491110.0   4.13
# 247    122698317.0  192928947.0  18.03
# 248    103572826.0  103500000.0   1.88
# 249            NaN          NaN    NaN

# %%
# Duplicate movie titles are due to movie being re-released years later. 
# Keep all rows and create new col 'title_yr'. 
df_revenue['title_yr'] = df_revenue['title'].str.cat(df_revenue.year.astype(str), sep = '-')
df_revenue.head()
# Out:
#                         title  id release_date  production_budget  \
# 0                     #Horror  16   2015-11-20          1500000.0
# 1        (500) Days of Summer  55   2009-07-17          7500000.0
# 2         10 Cloverfield Lane  54   2016-03-11          5000000.0
# 3       10 Days in a Madhouse  48   2015-11-11         12000000.0
# 4  10 Things I Hate About You  63   1999-03-31         13000000.0
#
#    domestic_gross  worldwide_gross  year studio  foreign_gross  net_revenue  \
# 0             NaN              NaN  2015    NaN            NaN          NaN
# 1      32425665.0       34439060.0  2009    NaN      2013395.0   26939060.0
# 2      72082999.0      108286422.0  2016   Par.     36203423.0  103286422.0
# 3         14616.0          14616.0  2015    NaN            NaN  -11985384.0
# 4      38177966.0       60413950.0  1999    NaN     22235984.0   47413950.0
#
#      ROI                         title_yr
# 0    NaN                     #Horror-2015
# 1   3.59        (500) Days of Summer-2009
# 2  20.66         10 Cloverfield Lane-2016
# 3  -1.00       10 Days in a Madhouse-2015
# 4   3.65  10 Things I Hate About You-1999

# %%
df_revenue[df_revenue['title_yr'].duplicated() == True]
# Out:
#      title  id release_date  production_budget  domestic_gross  \
# 2020  Home  60   2009-04-23           500000.0         15433.0
#
#       worldwide_gross  year studio  foreign_gross  net_revenue    ROI  \
# 2020       44793168.0  2009    NaN     44777735.0   44293168.0  88.59
#
#        title_yr
# 2020  Home-2009

# %%
df_revenue.sort_values('title').iloc[2017:2022, :]
# Out:
#             title  id release_date  production_budget  domestic_gross  \
# 2017  Holy Motors  25   2012-10-17          4000000.0        641054.0
# 2020         Home  60   2009-04-23           500000.0         15433.0
# 2019         Home  56   2009-06-05         12000000.0             NaN
# 2018         Home  44   2015-03-27        130000000.0     177397510.0
# 2021   Home Again  57   2017-09-08         15000000.0      27020284.0
#
#       worldwide_gross  year studio  foreign_gross  net_revenue    ROI  \
# 2017        4230426.0  2012     IM      3589372.0     230426.0   0.06
# 2020       44793168.0  2009    NaN     44777735.0   44293168.0  88.59
# 2019              NaN  2009    NaN            NaN          NaN    NaN
# 2018      385997896.0  2015    NaN    208600386.0  255997896.0   1.97
# 2021       37336874.0  2017    ORF     10316590.0   22336874.0   1.49
#
#               title_yr
# 2017  Holy Motors-2012
# 2020         Home-2009
# 2019         Home-2009
# 2018         Home-2015
# 2021   Home Again-2017

# %%
# Home movie - Double entry for 2009 release--unable to determine which one has accurate data, both appear to have notable outliers. Remove two 2009 entries.
df_revenue = df_revenue.drop([2018, 2019, 2020])
df_revenue.sort_values('title').iloc[2017:2022, :]
# Out:
#                                title  id release_date  production_budget  \
# 2017                     Holy Motors  25   2012-10-17          4000000.0
# 2021                      Home Again  57   2017-09-08         15000000.0
# 2022                      Home Alone  92   1990-11-16         15000000.0
# 2023  Home Alone 2: Lost in New York  89   1992-11-20         20000000.0
# 2024                      Home Fries  97   1998-11-25         15000000.0
#
#       domestic_gross  worldwide_gross  year studio  foreign_gross  \
# 2017        641054.0        4230426.0  2012     IM      3589372.0
# 2021      27020284.0       37336874.0  2017    ORF     10316590.0
# 2022     285761243.0      476684675.0  1990    NaN    190923432.0
# 2023     173585516.0      358994850.0  1992    NaN    185409334.0
# 2024      10513979.0       10513979.0  1998    NaN            NaN
#
#       net_revenue    ROI                             title_yr
# 2017     230426.0   0.06                     Holy Motors-2012
# 2021   22336874.0   1.49                      Home Again-2017
# 2022  461684675.0  30.78                      Home Alone-1990
# 2023  338994850.0  16.95  Home Alone 2: Lost in New York-1992
# 2024   -4486021.0  -0.30                      Home Fries-1998

# %%
df_revenue.describe()
# Out:
#              index           id  production_budget  domestic_gross  \
# count  5779.000000  5779.000000       5.779000e+03    5.232000e+03
# mean   2890.952414    50.370825       3.157950e+07    4.624124e+07
# std    1669.579098    28.828062       4.180009e+07    7.028365e+07
# min       0.000000     1.000000       1.100000e+03    3.880000e+02
# 25%    1444.500000    25.000000       5.000000e+06    4.296422e+06
# 50%    2892.000000    50.000000       1.700000e+07    2.198422e+07
# 75%    4336.500000    75.000000       4.000000e+07    5.750145e+07
# max    5781.000000   100.000000       4.250000e+08    9.366622e+08
#
#        worldwide_gross         year  foreign_gross   net_revenue          ROI
# count     5.413000e+03  5779.000000   4.161000e+03  5.413000e+03  5413.000000
# mean      9.764451e+07  2003.963488   6.888141e+07  6.434830e+07     4.110248
# std       1.788478e+08    12.726517   1.282446e+08  1.498629e+08    30.471380
# min       2.600000e+01  1915.000000   2.600000e+01 -2.002376e+08    -1.000000
# 25%       7.000000e+06  2000.000000   3.344243e+06 -1.865376e+06    -0.300000
# 50%       3.330000e+07  2007.000000   2.182656e+07  1.189133e+07     0.880000
# 75%       1.044296e+08  2012.000000   7.566976e+07  6.735617e+07     2.970000
# max       2.776345e+09  2020.000000   2.015838e+09  2.351345e+09  1799.000000

# %%
df_revenue.reset_index(inplace = True)

# %%
df_revenue.head()
# Out:
#    index                       title  id release_date  production_budget  \
# 0      0                     #Horror  16   2015-11-20          1500000.0
# 1      1        (500) Days of Summer  55   2009-07-17          7500000.0
# 2      2         10 Cloverfield Lane  54   2016-03-11          5000000.0
# 3      3       10 Days in a Madhouse  48   2015-11-11         12000000.0
# 4      4  10 Things I Hate About You  63   1999-03-31         13000000.0
#
#    domestic_gross  worldwide_gross  year studio  foreign_gross  net_revenue  \
# 0             NaN              NaN  2015    NaN            NaN          NaN
# 1      32425665.0       34439060.0  2009    NaN      2013395.0   26939060.0
# 2      72082999.0      108286422.0  2016   Par.     36203423.0  103286422.0
# 3         14616.0          14616.0  2015    NaN            NaN  -11985384.0
# 4      38177966.0       60413950.0  1999    NaN     22235984.0   47413950.0
#
#      ROI                         title_yr
# 0    NaN                     #Horror-2015
# 1   3.59        (500) Days of Summer-2009
# 2  20.66         10 Cloverfield Lane-2016
# 3  -1.00       10 Days in a Madhouse-2015
# 4   3.65  10 Things I Hate About You-1999

# %%
df_revenue[df_revenue['title_yr'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [index, title, id, release_date, production_budget, domestic_gross, worldwide_gross, year, studio, foreign_gross, net_revenue, ROI, title_yr]
# Index: []

# %%
# Set index to 'title'.
df_revenue = df_revenue.set_index('title')

# %%
df_revenue['worldwide_gross'].describe()
# Out:
# count    5.413000e+03
# mean     9.764451e+07
# std      1.788478e+08
# min      2.600000e+01
# 25%      7.000000e+06
# 50%      3.330000e+07
# 75%      1.044296e+08
# max      2.776345e+09
# Name: worldwide_gross, dtype: float64

# %%
display(df_revenue.info())
display(df_revenue[["production_budget", "domestic_gross", "worldwide_gross", "foreign_gross", "net_revenue", "ROI"]].apply(['mean', 'median', 'std']))
display(df_revenue.quantile(q=0.75))
display(df_revenue.quantile(q=0.95))
# outliers in normal distribution 
df_revenue.quantile(q=.99)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5779 entries, 0 to 5778
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              5779 non-null   object
#  1   index              5779 non-null   int64
#  2   id                 5779 non-null   int64
#  3   release_date       5779 non-null   datetime64[ns]
#  4   production_budget  5779 non-null   float64
#  5   domestic_gross     5232 non-null   float64
#  6   worldwide_gross    5413 non-null   float64
#  7   year               5779 non-null   int64
#  8   studio             1246 non-null   object
#  9   foreign_gross      4161 non-null   float64
#  10  net_revenue        5413 non-null   float64
#  11  ROI                5413 non-null   float64
#  12  title_yr           5779 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(3)
# memory usage: 587.1+ KB
# None
#         production_budget  domestic_gross  worldwide_gross  foreign_gross  \
# mean         3.157950e+07    4.624124e+07     9.764451e+07   6.888141e+07
# median       1.700000e+07    2.198422e+07     3.330000e+07   2.182656e+07
# std          4.180009e+07    7.028365e+07     1.788478e+08   1.282446e+08
#
#          net_revenue        ROI
# mean    6.434830e+07   4.110248
# median  1.189133e+07   0.880000
# std     1.498629e+08  30.471380
# index                4.336500e+03
# id                   7.500000e+01
# production_budget    4.000000e+07
# domestic_gross       5.750145e+07
# worldwide_gross      1.044296e+08
# year                 2.012000e+03
# foreign_gross        7.566976e+07
# net_revenue          6.735617e+07
# ROI                  2.970000e+00
# Name: 0.75, dtype: float64
# index                5.492100e+03
# id                   9.500000e+01
# production_budget    1.200000e+08
# domestic_gross       1.765328e+08
# worldwide_gross      4.103320e+08
# year                 2.017000e+03
# foreign_gross        3.010677e+08
# net_revenue          3.187214e+08
# ROI                  1.234400e+01
# Name: 0.95, dtype: float64
# index                5.723220e+03
# id                   9.900000e+01
# production_budget    2.000000e+08
# domestic_gross       3.369482e+08
# worldwide_gross      8.939423e+08
# year                 2.019000e+03
# foreign_gross        6.412303e+08
# net_revenue          7.646151e+08
# ROI                  5.428240e+01
# Name: 0.99, dtype: float64

# %%
# Domestic and worldwide gross revenue, net revenue are positively skewed--mean is larger than median, with large outliers distorting the mean.

# %%
df_revenue.boxplot(column=['net_revenue'])

# %%
# Number of movies in 75th, 99th percentiles - By worldwide net revenue
print(f"Number of movies in 75th percentile: {len(df_revenue[df_revenue['net_revenue']>6.735617e+07])}")    
print(f"Number of movies in 99.5 percentile: {len(df_revenue[df_revenue['net_revenue']>3.187214e+08])}")
print(f"Number of movies in 99.9 percentile: {len(df_revenue[df_revenue['net_revenue']>7.646151e+08])}")
# Out:
# Number of movies in 75th percentile: 1353
# Number of movies in 99.5 percentile: 271
# Number of movies in 99.9 percentile: 55

# %%
# Identify top movies by worldwide net revenue
df_revenue.sort_values(by = ['net_revenue'], axis=0, ascending=[False], inplace=False,
               na_position='last', ignore_index=True)[['title', 'net_revenue']].head()
# Out:
#                                   title   net_revenue
# 0                                Avatar  2.351345e+09
# 1                               Titanic  2.008208e+09
# 2                Avengers: Infinity War  1.748134e+09
# 3  Star Wars Ep. VII: The Force Awakens  1.747311e+09
# 4                        Jurassic World  1.433855e+09

# %%
# Identify movies with worldwide net revenue in 75 percentile
nr_75p = df_revenue['net_revenue'].loc[lambda x: x>6.737924e+07].sort_values(ascending = False, ignore_index=True)
display(nr_75p.head())
# Out:
# 0    2.351345e+09
# 1    2.008208e+09
# 2    1.748134e+09
# 3    1.747311e+09
# 4    1.433855e+09
# Name: net_revenue, dtype: float64

# %%
# Identify movies with worldwide net revenue in 99.9 percentile

# Create new df
df_nr_999p = df_revenue[df_revenue.net_revenue >= 7.646151e+08].sort_values('net_revenue', ascending = False)
df_nr_999p.head()

# how to use .loc?
#nr_99_3p = df_revenue['net_revenue'].loc[lambda x: x>8.407595e+08].sort_values(ascending = False, ignore_index = True)
#nr_99_3p = df_revenue[['title','net_revenue']]['net_revenue'].loc[lambda x: x>8.407595e+08].sort_values(ascending = False, ignore_index = True)
# Out:
#                                      title  index  id release_date  \
# 443                                 Avatar    443   1   2009-12-18
# 5305                               Titanic   5308  43   1997-12-19
# 445                 Avengers: Infinity War    445   7   2018-04-27
# 3987  Star Wars Ep. VII: The Force Awakens   3990   6   2015-12-18
# 2347                        Jurassic World   2350  34   2015-06-12
#
#       production_budget  domestic_gross  worldwide_gross  year studio  \
# 443         425000000.0     760507625.0     2.776345e+09  2009    NaN
# 5305        200000000.0     659363944.0     2.208208e+09  1997    NaN
# 445         300000000.0     678815482.0     2.048134e+09  2018     BV
# 3987        306000000.0     936662225.0     2.053311e+09  2015    NaN
# 2347        215000000.0     652270625.0     1.648855e+09  2015   Uni.
#
#       foreign_gross   net_revenue    ROI  \
# 443    2.015838e+09  2.351345e+09   5.53
# 5305   1.548844e+09  2.008208e+09  10.04
# 445    1.369319e+09  1.748134e+09   5.83
# 3987   1.116649e+09  1.747311e+09   5.71
# 2347   9.965842e+08  1.433855e+09   6.67
#
#                                        title_yr
# 443                                 Avatar-2009
# 5305                               Titanic-1997
# 445                 Avengers: Infinity War-2018
# 3987  Star Wars Ep. VII: The Force Awakens-2015
# 2347                        Jurassic World-2015

# %%
# Graph net revenue and ROI of movies in 99.9 percentile

ax1 = df_nr_999p.plot.barh(x= 'title', y= 'net_revenue', color = 'blue', stacked=False, rot=0, figsize=(12,10))
ax1.set(
    title='Net Revenue - Movies in 99th Percentile',
    xlabel='Billions $',
    ylabel='Movies')
ax1.invert_yaxis()

ax2 = df_nr_999p.plot.barh(x= 'title', y = 'ROI', color = 'green', stacked=False, rot=0, figsize=(12,10))
ax2.set(
    title='ROI - Movies in 99th Percentile',
    xlabel='ROI (x)',
    ylabel='Movies')
ax2.invert_yaxis()

plt.style.use('ggplot')
plt.show()
# Out:
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Is movie industry profitable? Analysis w/o outliers

# Create ROI df, remove NaN
df_roi = df_revenue[df_revenue['ROI'].notnull()]
df_roi.head()
# Out:
#                         title  index  id release_date  production_budget  \
# 1        (500) Days of Summer      1  55   2009-07-17          7500000.0
# 2         10 Cloverfield Lane      2  54   2016-03-11          5000000.0
# 3       10 Days in a Madhouse      3  48   2015-11-11         12000000.0
# 4  10 Things I Hate About You      4  63   1999-03-31         13000000.0
# 5                 10,000 B.C.      5  51   2008-03-07        105000000.0
#
#    domestic_gross  worldwide_gross  year studio  foreign_gross  net_revenue  \
# 1      32425665.0       34439060.0  2009    NaN      2013395.0   26939060.0
# 2      72082999.0      108286422.0  2016   Par.     36203423.0  103286422.0
# 3         14616.0          14616.0  2015    NaN            NaN  -11985384.0
# 4      38177966.0       60413950.0  1999    NaN     22235984.0   47413950.0
# 5      94784201.0      269065678.0  2008    NaN    174281477.0  164065678.0
#
#      ROI                         title_yr
# 1   3.59        (500) Days of Summer-2009
# 2  20.66         10 Cloverfield Lane-2016
# 3  -1.00       10 Days in a Madhouse-2015
# 4   3.65  10 Things I Hate About You-1999
# 5   1.56                 10,000 B.C.-2008

# %%
# Look into ROI outlier (max value)
df_roi.boxplot(column=['ROI'])

# %%
# Outlier detection
max_roi_threshold = df_roi['ROI'].quantile(0.95) 
min_roi_threshold = df_roi['ROI'].quantile(0.05)
print(f"Max ROI w/o outliers: {max_roi_threshold.round(2)}")
print(f"Min ROI w/o outliers: {min_roi_threshold.round(2)}")
# Out:
# Max ROI w/o outliers: 12.33
# Min ROI w/o outliers: -0.96

# %%
display(df_revenue[df_revenue['ROI'] > max_roi_threshold])
display(df_revenue[df_revenue['ROI'] < min_roi_threshold])
# Out:
#                              title  index  id release_date  production_budget  \
# 2              10 Cloverfield Lane      2  54   2016-03-11          5000000.0
# 33    20,000 Leagues Under the Sea     33  15   1916-12-24           200000.0
# 37         2016: Obamaâs America     37  13   2012-07-13          2500000.0
# 110                  A Ghost Story    110  86   2017-07-07           100000.0
# 116                A Haunted House    116  12   2013-01-11          2500000.0
# ...                            ...    ...  ..          ...                ...
# 5688                        Wonder   5691  95   2017-11-17         20000000.0
# 5695                     Woodstock   5698   8   1970-03-26           600000.0
# 5738                   You're Next   5741  17   2013-08-23          1000000.0
# 5742            Young Frankenstein   5745  84   1974-12-15          2800000.0
# 5746          Your Sister's Sister   5749  73   2012-06-15           120000.0
#
#       domestic_gross  worldwide_gross  year studio  foreign_gross  \
# 2         72082999.0      108286422.0  2016   Par.     36203423.0
# 33         8000000.0        8000000.0  1916    NaN            NaN
# 37        33349941.0       33349941.0  2012    NaN            NaN
# 110        1594798.0        2769782.0  2017    A24      1174984.0
# 116       40041683.0       59922558.0  2013    ORF     19880875.0
# ...              ...              ...   ...    ...            ...
# 5688     132422809.0      304604712.0  2017    LGF    172181903.0
# 5695      34505110.0       34505110.0  1970    NaN            NaN
# 5738      18494006.0       26887177.0  2013    LGF      8393171.0
# 5742      86300000.0       86300000.0  1974    NaN            NaN
# 5746       1597486.0        3090593.0  2012    IFC      1493107.0
#
#       net_revenue    ROI                           title_yr
# 2     103286422.0  20.66           10 Cloverfield Lane-2016
# 33      7800000.0  39.00  20,000 Leagues Under the Sea-1916
# 37     30849941.0  12.34       2016: Obamaâs America-2012
# 110     2669782.0  26.70                 A Ghost Story-2017
# 116    57422558.0  22.97               A Haunted House-2013
# ...           ...    ...                                ...
# 5688  284604712.0  14.23                        Wonder-2017
# 5695   33905110.0  56.51                     Woodstock-1970
# 5738   25887177.0  25.89                   You're Next-2013
# 5742   83500000.0  29.82            Young Frankenstein-1974
# 5746    2970593.0  24.75          Your Sister's Sister-2012
#
# [272 rows x 13 columns]
#                       title  index  id release_date  production_budget  \
# 3     10 Days in a Madhouse      3  48   2015-11-11         12000000.0
# 7               10th & Wolf      7  32   2006-08-18          8000000.0
# 17                  13 Sins     17  51   2014-04-18          4000000.0
# 21               16 to Life     21  90   2010-09-03          1000000.0
# 74            5 Days of War     74  47   2011-08-19         12000000.0
# ...                     ...    ...  ..          ...                ...
# 5675         Without Limits   5678  16   1998-09-11         25000000.0
# 5682                 Wolves   5685  51   2014-11-14         18000000.0
# 5699   World's Greatest Dad   5702  10   2009-08-21         10000000.0
# 5725    Yi ge ren de wu lin   5728  20   2015-04-24         25000000.0
# 5727            Yoga Hosers   5730  86   2016-09-02          5000000.0
#
#       domestic_gross  worldwide_gross  year studio  foreign_gross  \
# 3            14616.0          14616.0  2015    NaN            NaN
# 7            54702.0         143782.0  2006    NaN        89080.0
# 17            9134.0          47552.0  2014   RTWC        38418.0
# 21           11574.0          11574.0  2010    NaN            NaN
# 74           17479.0          87793.0  2011  Anch.        70314.0
# ...              ...              ...   ...    ...            ...
# 5675        780326.0         780326.0  1998    NaN            NaN
# 5682             NaN          94953.0  2014     KE        94953.0
# 5699        221805.0         295750.0  2009    NaN        73945.0
# 5725        129115.0         129115.0  2015    NaN            NaN
# 5727             NaN          22958.0  2016    NaN        22958.0
#
#       net_revenue   ROI                    title_yr
# 3     -11985384.0 -1.00  10 Days in a Madhouse-2015
# 7      -7856218.0 -0.98            10th & Wolf-2006
# 17     -3952448.0 -0.99                13 Sins-2014
# 21      -988426.0 -0.99             16 to Life-2010
# 74    -11912207.0 -0.99          5 Days of War-2011
# ...           ...   ...                         ...
# 5675  -24219674.0 -0.97         Without Limits-1998
# 5682  -17905047.0 -0.99                 Wolves-2014
# 5699   -9704250.0 -0.97   World's Greatest Dad-2009
# 5725  -24870885.0 -0.99    Yi ge ren de wu lin-2015
# 5727   -4977042.0 -1.00            Yoga Hosers-2016
#
# [267 rows x 13 columns]

# %%
# new DF without ROI outliers
df_roi_v2 = df_revenue[(df_revenue['ROI'] < max_roi_threshold) & (df_revenue['ROI'] > min_roi_threshold)]
display(df_roi_v2.sort_values('ROI', ascending = False).head(10))
# Out:
#                               title  index  id release_date  \
# 67    4 luni, 3 saptamani si 2 zile     67  40   2008-01-25
# 568            Bend it Like Beckham    568   8   2003-03-12
# 4590                   The Hangover   4593  25   2009-06-05
# 5105           The Spy Who Loved Me   5108  83   1977-07-13
# 2609                     Lola rennt   2612  35   1999-06-18
# 4984                The Puffy Chair   4987  60   2006-06-02
# 530     Beasts of the Southern Wild    530  18   2012-06-27
# 4577              The Green Inferno   4580  31   2015-09-25
# 2378     Kevin Hart: Let Me Explain   2381  14   2013-07-03
# 3666             Schindlerâs List   3669  69   1993-12-15
#
#       production_budget  domestic_gross  worldwide_gross  year   studio  \
# 67             900000.0       1196321.0       11993156.0  2008      NaN
# 568           5600000.0      32543449.0       74566042.0  2003      NaN
# 4590         35000000.0     277322503.0      465764086.0  2009      NaN
# 5105         14000000.0      46800000.0      185400000.0  1977      NaN
# 2609          1750000.0       7267324.0       22879194.0  1999      NaN
# 4984            15000.0        194523.0         195254.0  2006      NaN
# 530           1800000.0      12795746.0       23265132.0  2012     FoxS
# 4577          1000000.0       7192291.0       12931420.0  2015  BH Tilt
# 2378          2500000.0      32244051.0       32327255.0  2013     LG/S
# 3666         25000000.0      96898818.0      322197132.0  1993      NaN
#
#       foreign_gross  net_revenue    ROI                            title_yr
# 67       10796835.0   11093156.0  12.33  4 luni, 3 saptamani si 2 zile-2008
# 568      42022593.0   68966042.0  12.32           Bend it Like Beckham-2003
# 4590    188441583.0  430764086.0  12.31                   The Hangover-2009
# 5105    138600000.0  171400000.0  12.24           The Spy Who Loved Me-1977
# 2609     15611870.0   21129194.0  12.07                     Lola rennt-1999
# 4984          731.0     180254.0  12.02                The Puffy Chair-2006
# 530      10469386.0   21465132.0  11.93    Beasts of the Southern Wild-2012
# 4577      5739129.0   11931420.0  11.93              The Green Inferno-2015
# 2378        83204.0   29827255.0  11.93     Kevin Hart: Let Me Explain-2013
# 3666    225298314.0  297197132.0  11.89             Schindlerâs List-1993

# %%
display(df_roi.describe())
df_roi_v2.describe()
# Out:
#              index           id  production_budget  domestic_gross  \
# count  5412.000000  5412.000000       5.412000e+03    5.231000e+03
# mean   2903.830562    50.227827       3.330235e+07    4.624148e+07
# std    1663.385112    28.772652       4.247427e+07    7.029037e+07
# min       1.000000     1.000000       1.100000e+03    3.880000e+02
# 25%    1468.750000    25.000000       6.000000e+06    4.293070e+06
# 50%    2901.500000    50.000000       1.900000e+07    2.197318e+07
# 75%    4340.250000    75.000000       4.200000e+07    5.753371e+07
# max    5781.000000   100.000000       4.250000e+08    9.366622e+08
#
#        worldwide_gross         year  foreign_gross   net_revenue          ROI
# count     5.412000e+03  5412.000000   4.161000e+03  5.412000e+03  5412.000000
# mean      9.765423e+07  2003.602180   6.888141e+07  6.435188e+07     3.778598
# std       1.788629e+08    12.541916   1.282446e+08  1.498765e+08    18.253257
# min       2.600000e+01  1915.000000   2.600000e+01 -2.002376e+08    -1.000000
# 25%       7.000000e+06  1999.000000   3.344243e+06 -1.868580e+06    -0.300000
# 50%       3.325405e+07  2006.000000   2.182656e+07  1.188224e+07     0.880000
# 75%       1.044443e+08  2012.000000   7.566976e+07  6.736770e+07     2.962500
# max       2.776345e+09  2019.000000   2.015838e+09  2.351345e+09   497.750000
#              index           id  production_budget  domestic_gross  \
# count  4831.000000  4831.000000       4.831000e+03    4.708000e+03
# mean   2912.586628    50.111985       3.625571e+07    4.672810e+07
# std    1661.481320    28.929050       4.382799e+07    6.954400e+07
# min       1.000000     1.000000       5.000000e+03    5.270000e+02
# 25%    1482.500000    25.000000       8.000000e+06    5.792340e+06
# 50%    2916.000000    50.000000       2.000000e+07    2.400119e+07
# 75%    4341.500000    75.000000       4.700000e+07    5.801306e+07
# max    5781.000000   100.000000       4.250000e+08    9.366622e+08
#
#        worldwide_gross         year  foreign_gross   net_revenue          ROI
# count     4.831000e+03  4831.000000   3.830000e+03  4.831000e+03  4831.000000
# mean      9.995157e+07  2003.894639   6.863450e+07  6.369586e+07     1.710083
# std       1.806496e+08    11.913572   1.289263e+08  1.490291e+08     2.600739
# min       5.270000e+02  1925.000000   1.540000e+02 -2.002376e+08    -0.950000
# 25%       9.802076e+06  2000.000000   4.160253e+06 -1.177041e+06    -0.170000
# 50%       3.623022e+07  2006.000000   2.208944e+07  1.316991e+07     0.910000
# 75%       1.072014e+08  2012.000000   7.269043e+07  6.694956e+07     2.660000
# max       2.776345e+09  2019.000000   2.015838e+09  2.351345e+09    12.330000

# %%
display(df_roi_v2.ROI.apply(['mean', 'median', 'std']))
# Out:
# mean      1.710083
# median    0.910000
# std       2.600739
# Name: ROI, dtype: float64

# %%
#create new ROI buckets column 
def ROI_buckets(r):
    if r < 0: 
        return 'Not profitable'
    if r <= 1 : 
        return '0x - 1x'
    elif r <= 2: 
        return '1x - 2x'
    elif r <= 3: 
        return '2x - 3x'
    elif r <= 4: 
        return '3x - 4x'
    elif r <= 5: 
        return '4x - 5x'
    elif r <= 6: 
        return '5x - 6x'    
    elif r <= 7:
        return '6x - 7x'
    elif r <= 8:
        return '7x - 8x'
    elif r <= 9:
        return '8x - 9x'
    elif r <= 10:
        return '9x - 10x'
    elif r < 11:
        return '10x - 11x'
    elif r < 12:
        return '11x - 12x'
    elif r < 13:
        return '12x -13x'
    else: 
        return 'Not rated'

df_roi_v2['ROI_buckets'] = df_roi_v2['ROI'].apply(ROI_buckets)
df_roi_v2.head(10)
# Out:
# /Users/Magali/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                          title  index  id release_date  production_budget  \
# 1         (500) Days of Summer      1  55   2009-07-17          7500000.0
# 4   10 Things I Hate About You      4  63   1999-03-31         13000000.0
# 5                  10,000 B.C.      5  51   2008-03-07        105000000.0
# 6               102 Dalmatians      6   6   2000-11-22         85000000.0
# 10                  12 Monkeys     10  18   1995-12-27         29000000.0
# 11                   12 Rounds     11  37   2009-03-27         20000000.0
# 12                   12 Strong     12  64   2018-01-19         35000000.0
# 13            12 Years a Slave     13  18   2013-10-18         20000000.0
# 14                   127 Hours     14   6   2010-11-05         18000000.0
# 15              13 Going On 30     15  96   2004-04-23         37000000.0
#
#     domestic_gross  worldwide_gross  year studio  foreign_gross  net_revenue  \
# 1       32425665.0       34439060.0  2009    NaN      2013395.0   26939060.0
# 4       38177966.0       60413950.0  1999    NaN     22235984.0   47413950.0
# 5       94784201.0      269065678.0  2008    NaN    174281477.0  164065678.0
# 6       66941559.0       66941559.0  2000    NaN            NaN  -18058441.0
# 10      57141459.0      168841459.0  1995    NaN    111700000.0  139841459.0
# 11      12234694.0       17306648.0  2009    NaN      5071954.0   -2693352.0
# 12      45819713.0       71118378.0  2018     WB     25298665.0   36118378.0
# 13      56671993.0      181025343.0  2013   FoxS    124353350.0  161025343.0
# 14      18335230.0       60217171.0  2010   FoxS     41881941.0   42217171.0
# 15      57139723.0       97658712.0  2004    NaN     40518989.0   60658712.0
#
#      ROI                         title_yr     ROI_buckets
# 1   3.59        (500) Days of Summer-2009         3x - 4x
# 4   3.65  10 Things I Hate About You-1999         3x - 4x
# 5   1.56                 10,000 B.C.-2008         1x - 2x
# 6  -0.21              102 Dalmatians-2000  Not profitable
# 10  4.82                  12 Monkeys-1995         4x - 5x
# 11 -0.13                   12 Rounds-2009  Not profitable
# 12  1.03                   12 Strong-2018         1x - 2x
# 13  8.05            12 Years a Slave-2013         8x - 9x
# 14  2.35                   127 Hours-2010         2x - 3x
# 15  1.64              13 Going On 30-2004         1x - 2x

# %%
df_roi_v2['ROI_buckets'].value_counts(normalize = True).plot.bar(color = 'green')

# %%
## Explore distributions and relationships
df_roi_v2.plot.scatter(x = 'ROI',
                       y = 'production_budget', 
                       c = 'blue')
plt.show()

# %%
##! year_from2000 = df_roi_v2[df_roi_v2['year'] where year > 2000
df_roi_v2.plot.scatter(x = 'ROI',
                       y = 'year_from2000', 
                       c = 'blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year_from2000'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-361-aad61e44f0a9> in <module>
#       2 df_roi_v2.plot.scatter(x = 'ROI',
#       3                        y = 'year_from2000',
# ----> 4                        c = 'blue')
#       5 plt.show()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1497             ...                       colormap='viridis')
#    1498         """
# -> 1499         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1500
#    1501     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#     969         scatter = ax.scatter(
#     970             data[x].values,
# --> 971             data[y].values,
#     972             c=c_values,
#     973             label=label,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year_from2000'

# %%
# merge df_ROI_v2 with df4 (has info on genres, run time)

# %%
## Explore distributions and relationships
pd.plotting.scatter_matrix(df_revenue[['production_budget', 'domestic_gross', 'foreign_gross', 'worldwide_net_revenue']], figsize=(6,6));
plt.show()

# %%
# QUESTIONS

# %%
# glyphs

# %%
## Clean up: Rename columns, convert dtypes to prepare dfs for joins and analysis

# %%
df2 = df2.rename(columns={"nconst": "name_id"})
df2.head()

# %%
df4 = df4.rename(columns={"tconst": "title_id"})
df4.head()

# %%
df5 = df5.rename(columns={"tconst": "title_id"})
df5.head()

# %%
df6 = df6.rename(columns={"tconst": "title_id", "nconst": "name_id"})
df6.head()

# %%
df7 = df7.rename(columns={"tconst": "title_id"})
df7.head()

# %%
df8['theater_date'] = pd.to_datetime(df8['theater_date'])
df8['dvd_date'] = pd.to_datetime(df8['dvd_date'])
df8.info()

# %%
df8 = df8.rename(columns={"runtime": "runtime_mins"})
df8['runtime_mins'] = df8['runtime_mins'].str.rstrip('minutes')
df8.head()

# %%
df10['release_date'] = pd.to_datetime(df10['release_date'])
df10.info()

# %%
## Calculate worldwide_net_revenue and foreign_gross (revenue generated outside of US)
df11['worldwide_net_revenue'] = df11.worldwide_gross - df11.production_budget
df11['foreign_gross'] = df11.worldwide_gross - df11.domestic_gross

# %%
## Explore distributions and relationships
pd.plotting.scatter_matrix(df11[['production_budget', 'domestic_gross', 'foreign_gross','worldwide_gross', 'worldwide_net_revenue']], figsize=(6,6));
plt.show()

# %%
df11.apply(['mean', 'median', 'std'])

# %%
# Explore distribution of worldwide_net_revenue
fig, ax = plt.subplots(figsize=(6,6))
ax.hist(df11['worldwide_net_revenue'], bins='auto', alpha = 0.5)
ax.set_title('Distribution of Worldwide Net Revenue')
ax.set_xlabel('Net Revenue ($ Billions)')
ax.set_ylabel('Number of Movies')
ax.axvline(df11['worldwide_net_revenue'].mean(), color = 'black')
ax.axvline(df11['worldwide_net_revenue'].median(), color = 'red')

# %%
df11['worldwide_net_revenue'].describe()

# %%
# Worldwide net revenue is positively skewed--mean is larger than median, with large outliers distorting the mean.
# Identify movies with above-median worldwide net revenue
above_median_worldwide_net_revenue = []

#df11.query('worldwide_net_revenue'>=8.550286e+06)

movies = df11.movie.values
#ww_net_rev = df11.worldwide_net_revenue.values

if df11['worldwide_net_revenue'] >= 8.550286e+06:
    above_median_worldwide_net_revenue.append()

above_median_worldwide_net_revenue

# %%
# Explore distribution of worldwide_net_revenue

fig, ax = plt.subplots(4, figsize=(10,8))
ax1 = plt.subplot(1,4,1)
ax1.hist(df_revenue['net_revenue'], bins='auto', color = 'green', alpha = 0.5)
ax1.set_title('Net Revenue', fontsize = 10)
ax1.set_xlabel('Dollars $', fontsize = 10)
ax1.set_ylabel('Number of Movies', fontsize = 10)
ax1.axvline(df_revenue['net_revenue'].mean(), color = 'black')

ax2 = plt.subplot(1,4,2)
ax2.hist(df_revenue['domestic_gross'], bins='auto', color = 'green', alpha = 0.5)
ax2.set_title('Domestic Gross Revenue' , fontsize = 10)
ax2.set_xlabel('Dollars $', fontsize = 10)
ax2.axvline(df_revenue['domestic_gross'].mean(), color = 'black')

ax3 = plt.subplot(1,4,3)
ax3.hist(df_revenue['foreign_gross'], bins='auto', color = 'green', alpha = 0.5)
ax3.set_title('Foreign Gross Revenue', fontsize = 10)
ax3.set_xlabel('Dollars $', fontsize = 10)
ax3.axvline(df_revenue['foreign_gross'].mean(), color = 'black')

ax4 = plt.subplot(1,4,4)
ax4.hist(df_revenue['production_budget'], bins='auto', color = 'green', alpha = 0.5)
ax4.set_title('Production Budget', fontsize = 10)
ax4.set_xlabel('Dollars $', fontsize = 10)
ax4.axvline(df_revenue['production_budget'].mean(), color = 'black')

#plt.style.use('ggplot')
plt.show()
